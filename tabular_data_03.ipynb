# %% [markdown]
# # Data preparation: from raw to analyzable data

# %%
import pandas as pd
import numpy as np

# %%
import os
os.chdir('/Users/joshwinnes/Library/Mobile Documents/com~apple~CloudDocs/Wheaton College/fall 2024/topics in data science/data')
df = pd.read_csv('dhs_service_records_synthesized_final.csv')

# %% [markdown]
# ### revisit the making of some simple charts
#
# * many choices for plotting libraries, we uses two below
#
# * https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html
#
# * https://seaborn.pydata.org/examples/index.html

# %% [markdown]
# ### making a histogram for the age column in the data
#
# * using metplotlib.pyplot

# %%
import matplotlib.pyplot as plt
plt.hist(df['age'], bins = 20, color = 'blue', edgecolor = 'black', density=True)
plt.show()

# %%
plt.hist(df['age'], bins = 20, color = 'blue', edgecolor = 'black', density=True)

# add normal distribution to see the difference 
mu = df['age'].mean()
sigma = df['age'].std()
x = np.linspace(df['age'].min(), df['age'].max(), 100)
y = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (x - mu)**2 / (2 * sigma**2))

plt.plot(x, y, color = 'red')

plt.title('Age Histogram')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# * plot two charts side by side

# %%
fig, ((ax0, ax1)) = plt.subplots(nrows=1, ncols=2)

ax0.hist(df[df["GENDER"]=="1~Male"]["age"], bins=10, density=True, histtype='bar', color="red", edgecolor = "black")
ax0.set_title('Age Distribution of Male')

ax1.hist(df[df["GENDER"]=="2~Female"]["age"], bins=10, density=True, histtype='bar', color = "green", edgecolor = "black")
ax1.set_title('Age Distribution of Female')

fig.tight_layout()
plt.show()

# %% [markdown]
# * use seaborn library

# %%
import seaborn as sns
sns.displot(df['age'], bins = 20, color = 'blue')

# %%
sns.displot(df['age'], bins = 50, color = 'blue', kde = True)

# %%
sns.displot(df['age'], bins = 100, color = 'blue', kde=True)  # this kde does not look right

# %%
sns.displot(df['age'],color = 'blue', kde=True)  # this kde does not look right

# %% [markdown]
# ### to investigate the issue,
# * need to trace back the parameters
# * seaborn layers on top of metplotlib
# * sns.displot calls differet functions from within metplotlib, depending on the parameters, when bin number is bigger, or not given, displot calls different functions, the kde line stopps pairing with the height

# %%
sns.kdeplot(df['age'], color = 'blue')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# * make a boxplot of age, separated by gender

# %%
sns.boxplot(data = df, x = "GENDER", y = "age")
plt.title('Age Distribution of DHS Service')
plt.show()

# %% [markdown]
# * make a count plot

# %%
sns.countplot(x = df['EDUCATION_LEVEL'])
plt.title('Education Level Distribution')
plt.xlabel('Education Level')
plt.xticks(rotation=90)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# * to rotate the chart, just switch the x and y

# %%
sns.countplot(y = df['EDUCATION_LEVEL']) 
plt.title('Education Level Distribution')
plt.ylabel('Education Level')
plt.xlabel('Frequency')
plt.show()

# %% [markdown]
# * make a barplot

# %%
sns.barplot(data=df, x="RACE", y="age")
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby("RACE")["age"].mean()
# Out:
# RACE
# 1~White                               34.718632
# 2~Black/African American              30.469064
# 4~Asian                               29.758956
# 5~Native American/Pacific Islander    36.226246
# 6~Two or More Races                   19.323124
# 7~Other Single Race                   18.286362
# 99~Unknown                            19.512704
# Name: age, dtype: float64

# %% [markdown]
# ### Removing NA Columns and Rows
#
# * if we take a look of the data summary, we can spot the NA's

# %%
df.describe()
# Out:
#         MCI_UNIQ_ID   CALDR_YR  GEO_AREA           age  DOB  DOD  \
# count  7.116134e+06  7116134.0       0.0  7.116134e+06  0.0  0.0
# mean   2.674853e+05     2021.0       NaN  3.267702e+01  NaN  NaN
# std    1.544397e+05        0.0       NaN  2.258095e+01  NaN  NaN
# min    1.000000e+00     2021.0       NaN  0.000000e+00  NaN  NaN
# 25%    1.337730e+05     2021.0       NaN  1.300000e+01  NaN  NaN
# 50%    2.675410e+05     2021.0       NaN  3.000000e+01  NaN  NaN
# 75%    4.010820e+05     2021.0       NaN  4.900000e+01  NaN  NaN
# max    5.356080e+05     2021.0       NaN  1.210000e+02  NaN  NaN
#
#        GENDER_IDENTITY  SEX_ORIENT  LEGAL_SEX  LIVING_ARRANGEMENT  \
# count              0.0         0.0        0.0                 0.0
# mean               NaN         NaN        NaN                 NaN
# std                NaN         NaN        NaN                 NaN
# min                NaN         NaN        NaN                 NaN
# 25%                NaN         NaN        NaN                 NaN
# 50%                NaN         NaN        NaN                 NaN
# 75%                NaN         NaN        NaN                 NaN
# max                NaN         NaN        NaN                 NaN
#
#        EMPLOYMENT_STATUS  VETERAN_FLAG
# count                0.0           0.0
# mean                 NaN           NaN
# std                  NaN           NaN
# min                  NaN           NaN
# 25%                  NaN           NaN
# 50%                  NaN           NaN
# 75%                  NaN           NaN
# max                  NaN           NaN

# %% [markdown]
# * To drop NaN values, we can use a simple function called `df.dropna()`.

# %%
df.dropna(how='all', inplace=True)
df.shape
# Out:
# (7116134, 20)

# %% [markdown]
# Note to collaborators: dropping all NA rows like this has no effect as there are no rows of only NA values.
#
# With this function, the default parameter for a hidden value `axis` removed rows of only NA values. To remove columns, we need to specify the axis.

# %%
#we want to remove any of the rows that have only NA values.
df.dropna(axis=1, how='all', inplace=True)
df.shape
# Out:
# (7116134, 11)

# %% [markdown]
# df.dropna(inplace=True)  will drop rows with any NA.
#
# Note: I am still going to include code that would remove rows with only NA values, even though it is not relevant for this dataset. Github copilot says that df.dropna(axis=0, how='all', inplace=True) works, and I trust it for the moment.
#
# Now what if we wanted to drop a row with a single NA value? We can simply remove the how='all' parameter and it will remove the rows with at least one NA value.

# %% [markdown]
# We can also drop the columns that has only one value in its entirety as they have not information.

# %%
df.drop(['synthetic_data', 'CALDR_YR'], axis=1, inplace=True)
df.shape
# Out:
# (7116134, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7116134 entries, 0 to 7116133
# Data columns (total 9 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   MCI_UNIQ_ID      int64
#  1   DATE_OF_EVENT    object
#  2   service          object
#  3   age              int64
#  4   GENDER           object
#  5   RACE             object
#  6   ETHNICITY        object
#  7   MARITAL_STATUS   object
#  8   EDUCATION_LEVEL  object
# dtypes: int64(2), object(7)
# memory usage: 488.6+ MB

# %% [markdown]
# We can also lower case the columns for ease of work

# %%
df[df.MCI_UNIQ_ID==25958]
# Out:
#          MCI_UNIQ_ID DATE_OF_EVENT                                service  \
# 1227119        25958    01/31/2021  Individuals_Receiving_Income_Supports
# 1227120        25958    02/28/2021  Individuals_Receiving_Income_Supports
# 1227121        25958    03/31/2021  Individuals_Receiving_Income_Supports
# 1227122        25958    04/30/2021  Individuals_Receiving_Income_Supports
# 1227123        25958    05/31/2021  Individuals_Receiving_Income_Supports
# 1227124        25958    06/30/2021  Individuals_Receiving_Income_Supports
# 1227125        25958    07/31/2021  Individuals_Receiving_Income_Supports
# 1227126        25958    08/31/2021  Individuals_Receiving_Income_Supports
# 1227127        25958    09/30/2021  Individuals_Receiving_Income_Supports
# 1227128        25958    10/31/2021  Individuals_Receiving_Income_Supports
# 1227129        25958    11/30/2021  Individuals_Receiving_Income_Supports
# 1227130        25958    12/31/2021  Individuals_Receiving_Income_Supports
#
#          age  GENDER                      RACE   ETHNICITY  \
# 1227119  121  1~Male  2~Black/African American  99~Unknown
# 1227120  121  1~Male  2~Black/African American  99~Unknown
# 1227121  121  1~Male  2~Black/African American  99~Unknown
# 1227122  121  1~Male  2~Black/African American  99~Unknown
# 1227123  121  1~Male  2~Black/African American  99~Unknown
# 1227124  121  1~Male  2~Black/African American  99~Unknown
# 1227125  121  1~Male  2~Black/African American  99~Unknown
# 1227126  121  1~Male  2~Black/African American  99~Unknown
# 1227127  121  1~Male  2~Black/African American  99~Unknown
# 1227128  121  1~Male  2~Black/African American  99~Unknown
# 1227129  121  1~Male  2~Black/African American  99~Unknown
# 1227130  121  1~Male  2~Black/African American  99~Unknown
#
#                  MARITAL_STATUS                EDUCATION_LEVEL
# 1227119  1~Single-Never Married  9-12~High School (grade 9-12)
# 1227120  1~Single-Never Married  9-12~High School (grade 9-12)
# 1227121  1~Single-Never Married  9-12~High School (grade 9-12)
# 1227122  1~Single-Never Married  9-12~High School (grade 9-12)
# 1227123  1~Single-Never Married  9-12~High School (grade 9-12)
# 1227124  1~Single-Never Married  9-12~High School (grade 9-12)
# 1227125  1~Single-Never Married  9-12~High School (grade 9-12)
# 1227126  1~Single-Never Married  9-12~High School (grade 9-12)
# 1227127  1~Single-Never Married  9-12~High School (grade 9-12)
# 1227128  1~Single-Never Married  9-12~High School (grade 9-12)
# 1227129  1~Single-Never Married  9-12~High School (grade 9-12)
# 1227130  1~Single-Never Married  9-12~High School (grade 9-12)

# %%
df.rename(columns=str.lower, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7116134 entries, 0 to 7116133
# Data columns (total 9 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   mci_uniq_id      int64
#  1   date_of_event    object
#  2   service          object
#  3   age              int64
#  4   gender           object
#  5   race             object
#  6   ethnicity        object
#  7   marital_status   object
#  8   education_level  object
# dtypes: int64(2), object(7)
# memory usage: 488.6+ MB

# %% [markdown]
# ## change column names for ease of work

# %%
df.rename(columns = {'mci_uniq_id': 'id', 
                    'date_of_event': 'date', 
                    'marital_status': 'marital', 
                    'education_level':'education'}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7116134 entries, 0 to 7116133
# Data columns (total 9 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   id         int64
#  1   date       object
#  2   service    object
#  3   age        int64
#  4   gender     object
#  5   race       object
#  6   ethnicity  object
#  7   marital    object
#  8   education  object
# dtypes: int64(2), object(7)
# memory usage: 488.6+ MB

# %%
df.shape
# Out:
# (7116134, 9)

# %%
df[df.id==25958]
# Out:
#             id        date                                service  age  \
# 1227119  25958  01/31/2021  Individuals_Receiving_Income_Supports  121
# 1227120  25958  02/28/2021  Individuals_Receiving_Income_Supports  121
# 1227121  25958  03/31/2021  Individuals_Receiving_Income_Supports  121
# 1227122  25958  04/30/2021  Individuals_Receiving_Income_Supports  121
# 1227123  25958  05/31/2021  Individuals_Receiving_Income_Supports  121
# 1227124  25958  06/30/2021  Individuals_Receiving_Income_Supports  121
# 1227125  25958  07/31/2021  Individuals_Receiving_Income_Supports  121
# 1227126  25958  08/31/2021  Individuals_Receiving_Income_Supports  121
# 1227127  25958  09/30/2021  Individuals_Receiving_Income_Supports  121
# 1227128  25958  10/31/2021  Individuals_Receiving_Income_Supports  121
# 1227129  25958  11/30/2021  Individuals_Receiving_Income_Supports  121
# 1227130  25958  12/31/2021  Individuals_Receiving_Income_Supports  121
#
#          gender                      race   ethnicity                 marital  \
# 1227119  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227120  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227121  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227122  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227123  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227124  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227125  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227126  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227127  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227128  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227129  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227130  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
#
#                              education
# 1227119  9-12~High School (grade 9-12)
# 1227120  9-12~High School (grade 9-12)
# 1227121  9-12~High School (grade 9-12)
# 1227122  9-12~High School (grade 9-12)
# 1227123  9-12~High School (grade 9-12)
# 1227124  9-12~High School (grade 9-12)
# 1227125  9-12~High School (grade 9-12)
# 1227126  9-12~High School (grade 9-12)
# 1227127  9-12~High School (grade 9-12)
# 1227128  9-12~High School (grade 9-12)
# 1227129  9-12~High School (grade 9-12)
# 1227130  9-12~High School (grade 9-12)

# %% [markdown]
# # Basic Transformations
#
# Often times when we encounter data, we find that it is in a format that is a bit clunky to use. Part of EDA will be to make datasets more friendly. Here we will go over four transformations: substitution, generation, outlier removal, and illogical value removal.
#
# ## Substitution
#
# For the data entries that have strings in certain columns, like "Individuals_Receiving_DHS_Services", we may need to alter these. Strings can be a bit clunky to work with and are generally read better for plots when we have them in categories. Additionally, we can try and do some mathematical tests on them when we have numerical category labels.

# %%
df.service.nunique()
# Out:
# 22

# %%
df.service.unique()
# Out:
# array(['Children_Attending_Early_Childhood_Programs_Managed_by_DHS',
#        'Children_in_Care', 'Children_Receiving_Child_Welfare_Services',
#        'Children_Receiving_DHS_Funded_Out_of_School_Programs',
#        'Children_Receiving_Early_Intervention_Services',
#        'Families_Receiving_Child_Welfare_Services', 'Homeless_Population',
#        'Homicides', 'Individuals_Receiving_DHS_Services',
#        'Individuals_Receiving_Family_Strengthening_Programs',
#        'Individuals_Receiving_Homelessness_and_Housing_Services',
#        'Individuals_Receiving_Income_Supports',
#        'Individuals_Receiving_Intellectual_Disability_Services',
#        'Individuals_Receiving_Mental_Health_Services',
#        'Individuals_Receiving_Substance_Use_Disorder_Services',
#        'Involuntary_Commitments', 'Jail_Population',
#        'Mental_Health_Crises', 'Older_Adults_Receiving_Services',
#        'Overdoses', 'Parents_Receiving_Child_Welfare_Services',
#        'Suicides'], dtype=object)

# %% [markdown]
# ## change some columns into catgorical type
#
# we want to turn the columns for gender, race, ethnicity, marital status, and education level into the category data type.

# %%
df = df.astype({'id':'category', 
                'service':'category',
                'age': 'int',
                'gender':'category',
                'race':'category',
                'marital':'category',
                'education':'category'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7116134 entries, 0 to 7116133
# Data columns (total 9 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   id         category
#  1   date       object
#  2   service    category
#  3   age        int64
#  4   gender     category
#  5   race       category
#  6   ethnicity  object
#  7   marital    category
#  8   education  category
# dtypes: category(6), int64(1), object(2)
# memory usage: 244.2+ MB

# %%
df[df.id==25958]
# Out:
#             id        date                                service  age  \
# 1227119  25958  01/31/2021  Individuals_Receiving_Income_Supports  121
# 1227120  25958  02/28/2021  Individuals_Receiving_Income_Supports  121
# 1227121  25958  03/31/2021  Individuals_Receiving_Income_Supports  121
# 1227122  25958  04/30/2021  Individuals_Receiving_Income_Supports  121
# 1227123  25958  05/31/2021  Individuals_Receiving_Income_Supports  121
# 1227124  25958  06/30/2021  Individuals_Receiving_Income_Supports  121
# 1227125  25958  07/31/2021  Individuals_Receiving_Income_Supports  121
# 1227126  25958  08/31/2021  Individuals_Receiving_Income_Supports  121
# 1227127  25958  09/30/2021  Individuals_Receiving_Income_Supports  121
# 1227128  25958  10/31/2021  Individuals_Receiving_Income_Supports  121
# 1227129  25958  11/30/2021  Individuals_Receiving_Income_Supports  121
# 1227130  25958  12/31/2021  Individuals_Receiving_Income_Supports  121
#
#          gender                      race   ethnicity                 marital  \
# 1227119  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227120  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227121  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227122  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227123  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227124  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227125  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227126  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227127  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227128  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227129  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
# 1227130  1~Male  2~Black/African American  99~Unknown  1~Single-Never Married
#
#                              education
# 1227119  9-12~High School (grade 9-12)
# 1227120  9-12~High School (grade 9-12)
# 1227121  9-12~High School (grade 9-12)
# 1227122  9-12~High School (grade 9-12)
# 1227123  9-12~High School (grade 9-12)
# 1227124  9-12~High School (grade 9-12)
# 1227125  9-12~High School (grade 9-12)
# 1227126  9-12~High School (grade 9-12)
# 1227127  9-12~High School (grade 9-12)
# 1227128  9-12~High School (grade 9-12)
# 1227129  9-12~High School (grade 9-12)
# 1227130  9-12~High School (grade 9-12)

# %% [markdown]
# ## Generating new variabes
# In other cases, we may want to generate a new variable. These can simply be combinations of previous variables, but in the case of this dataset, we will convert the "age" column to a categorical datatype variable as well. We will do this by putting ages in bins of 10 years.

# %%
#first we will define a helper function that takes in an int
#and returns the corresponding age bin value (grouped by 10), so a 5 gets returned as "0-9"
def age_bin(age):
    if age < 10:
        return "0-9"
    elif age < 20:
        return "10-19"
    elif age < 30:
        return "20-29"
    elif age < 40:
        return "30-39"
    elif age < 50:
        return "40-49"
    elif age < 60:
        return "50-59"
    elif age < 70:
        return "60-69"
    elif age < 80:
        return "70-79"
    elif age < 90:
        return "80-89"
    else:
        return "90+"
    
#is there a better way to do this? I am not sure, but we will go with this anyway. 
#it gets the job done.

#we will now apply this function to the age column and create a new column called AGE_BIN
df["age_bin"] = df["age"].apply(age_bin).astype('category')
df.head()
# Out:
#      id        date                                            service  age  \
# 0  1626  01/31/2021  Children_Attending_Early_Childhood_Programs_Ma...    5
# 1  1626  02/28/2021  Children_Attending_Early_Childhood_Programs_Ma...    5
# 2  1626  03/31/2021  Children_Attending_Early_Childhood_Programs_Ma...    5
# 3  1626  04/30/2021  Children_Attending_Early_Childhood_Programs_Ma...    5
# 4  1626  05/31/2021  Children_Attending_Early_Childhood_Programs_Ma...    5
#
#    gender     race   ethnicity     marital                      education  \
# 0  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
# 1  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
# 2  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
# 3  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
# 4  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
#
#   age_bin
# 0     0-9
# 1     0-9
# 2     0-9
# 3     0-9
# 4     0-9

# %%
df.groupby("age_bin").count().sort_values(by="id",ascending=False)
# Out:
# /var/folders/99/6591xgpn4sq1ypfgnrzy_7n80000gn/T/ipykernel_27369/2439735706.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("age_bin").count().sort_values(by="id",ascending=False)
#               id     date  service      age   gender     race  ethnicity  \
# age_bin
# 0-9      1287297  1287297  1287297  1287297  1287297  1287297    1287297
# 10-19    1169627  1169627  1169627  1169627  1169627  1169627    1169627
# 30-39    1145436  1145436  1145436  1145436  1145436  1145436    1145436
# 20-29    1014389  1014389  1014389  1014389  1014389  1014389    1014389
# 40-49     763619   763619   763619   763619   763619   763619     763619
# 50-59     674008   674008   674008   674008   674008   674008     674008
# 60-69     594030   594030   594030   594030   594030   594030     594030
# 70-79     253942   253942   253942   253942   253942   253942     253942
# 80-89     142763   142763   142763   142763   142763   142763     142763
# 90+        71023    71023    71023    71023    71023    71023      71023
#
#          marital  education
# age_bin
# 0-9      1287297    1287297
# 10-19    1169627    1169627
# 30-39    1145436    1145436
# 20-29    1014389    1014389
# 40-49     763619     763619
# 50-59     674008     674008
# 60-69     594030     594030
# 70-79     253942     253942
# 80-89     142763     142763
# 90+        71023      71023

# %% [markdown]
# ## Working with date
#
# We can generating additional variables for months in which the recipients use the service, for instance.
#
# We can do this by string operation, ie., to split the date of event so we get the month in which each service occurs. We can do this by simply getting the first two characters of the `date` column.

# %%
#make a new month column
#this is the first two characters of the date column and the last 5 characters of the column
df["month_str"] = df["date"].str[:2] + df["date"].str[-5:]
df.head()
# Out:
#      id        date                                            service  age  \
# 0  1626  01/31/2021  Children_Attending_Early_Childhood_Programs_Ma...    5
# 1  1626  02/28/2021  Children_Attending_Early_Childhood_Programs_Ma...    5
# 2  1626  03/31/2021  Children_Attending_Early_Childhood_Programs_Ma...    5
# 3  1626  04/30/2021  Children_Attending_Early_Childhood_Programs_Ma...    5
# 4  1626  05/31/2021  Children_Attending_Early_Childhood_Programs_Ma...    5
#
#    gender     race   ethnicity     marital                      education  \
# 0  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
# 1  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
# 2  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
# 3  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
# 4  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
#
#   age_bin month_str
# 0     0-9   01/2021
# 1     0-9   02/2021
# 2     0-9   03/2021
# 3     0-9   04/2021
# 4     0-9   05/2021

# %% [markdown]
# More appropriately, and easily, is to cast the "date" column into datetime type, which will give us many useful functions that works on datetime types.

# %%
df['date'] = pd.to_datetime(df['date'])
df['month'] = df["date"].dt.month_name()
df.head()
# Out:
#      id       date                                            service  age  \
# 0  1626 2021-01-31  Children_Attending_Early_Childhood_Programs_Ma...    5
# 1  1626 2021-02-28  Children_Attending_Early_Childhood_Programs_Ma...    5
# 2  1626 2021-03-31  Children_Attending_Early_Childhood_Programs_Ma...    5
# 3  1626 2021-04-30  Children_Attending_Early_Childhood_Programs_Ma...    5
# 4  1626 2021-05-31  Children_Attending_Early_Childhood_Programs_Ma...    5
#
#    gender     race   ethnicity     marital                      education  \
# 0  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
# 1  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
# 2  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
# 3  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
# 4  1~Male  1~White  99~Unknown  99~Unknown  9-12~High School (grade 9-12)
#
#   age_bin month_str     month
# 0     0-9   01/2021   January
# 1     0-9   02/2021  February
# 2     0-9   03/2021     March
# 3     0-9   04/2021     April
# 4     0-9   05/2021       May

# %% [markdown]
# ## Outlier Removal
# Often times, data will have outliers. These are data points that are very far from the majority of the data. In the case of a dataset with all categorical variables, this is not often feasible. However, such an act is more common with numeric features. Let's try the age category and remove all the rows with age 105 or greater.

# %%
#want to remove all entries from the dataset where the age entry is 105 or more
df[df["age"] >= 110].age.unique()
# Out:
# array([121, 113])

# %%
df[df["age"] >= 90].age.unique()
# Out:
# array([ 98,  90,  96,  95,  92,  91, 102,  97,  94,  93, 104, 101, 107,
#         99, 100, 103, 105, 106, 108, 121, 109, 113])

# %%
df = df[df["age"] < 110] # this removes the records that have age greater than or equal to 110
df.shape
# Out:
# (7116098, 12)

# %% [markdown]
# ## Illogical Value Removal
# This portion of data transformations is slightly harder as we will have to look at multiple features at the same time. However, it is still important. Some data points in the dataset have children of age 5, yet lists them as in high school.

# %% [markdown]
# we may want to remove all the values where the age is 0-9 AND where they are listed as in high school as "9-12~High School (grade 9-12)".
#
# however, the number of receipients in this group seems to be rather high. As a synthetic dataset, this might be due to synthesis process/algorithm. The technical report on the synthetic dataset had mentioned that the synthetic data on rare combinations of more than one variables has bigger distnace from real data (in this case, it should be zero).
#
# If this is real data, this may indicate it is rather a data collection issue and not to dismissed.

# %%
df[((df["age_bin"] == "0-9") & (df["education"] == "9-12~High School (grade 9-12)"))].id.unique()
# Out:
# [1626, 5570, 6022, 7912, 9265, ..., 535587, 535608, 167753, 266643, 470350]
# Length: 43298
# Categories (533799, int64): [1, 2, 3, 4, ..., 535605, 535606, 535607, 535608]

# %% [markdown]
# # Advanced Transformations
#
# Sometimes when doing exploratory data analysis, the storage format of the table does not give a complete view of the picture. In the case of this dataset, we found earlier that there were several rows with the same ID, which means that there are multiple entries for some people. This indicates that they used the services provided in the dataset multiple times.
#
# To get a better picture of some data insights, we can make a new dataframe; this one will have one row for each ID, and we will add the columns regarding the number of services used, number of distinct services used, and the number of months the services were used. Because the dataset is big, this may take a while.
#
# In general cases, to find new transformations for the datasets you work with, you will need to think about the general direction to take the data, which can involve simply thinking about the data logically. However, a better approach is to consult domain knowledge. This basically involves looking to sources related to the data (research articles, people who collected the data, people who are knowledgeable on the subject) and transforming the data as they may advise, or getting advice on where to look for ideas on transformations.
#
# Here, we are going to perform two aggregative transformations. These will group the entries of the dataset by the ID, as well as by the (ID, Month) pairing and compute some summary statistics, including the number of services used, the number of months the services were used, and the range of dates the services were used.

# %%
df[df.id==25958]
# Out:
# Empty DataFrame
# Columns: [id, date, service, age, gender, race, ethnicity, marital, education, age_bin, month_str, month]
# Index: []

# %%
def get_recipient_attribute(df):
    recipient = df.groupby(['id']).agg(
        num_service = ('service', 'count'),
        distinct_service = ('service', 'nunique'), 
        first_date = ('date', 'min'), 
        last_date = ('date', 'max'), 
        num_month = ('month', 'count'), 
        distinct_month = ('month', 'nunique')
    ).reset_index()

    return recipient

# %% [markdown]
# * agg made "id" into index in the aggregation result
# * reset_index() put the old index ("id" in this case") into a column, and use sequential index

# %%
recipient = get_recipient_attribute(df)
recipient.head()
# Out:
# /var/folders/99/6591xgpn4sq1ypfgnrzy_7n80000gn/T/ipykernel_27369/2557517183.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   recipient = df.groupby(['id']).agg(
#   id  num_service  distinct_service first_date  last_date  num_month  \
# 0  1           12                 1 2021-01-31 2021-12-31         12
# 1  2            1                 1 2021-02-28 2021-02-28          1
# 2  3           11                 1 2021-02-28 2021-12-31         11
# 3  4            4                 1 2021-03-31 2021-12-31          4
# 4  5           12                 1 2021-01-31 2021-12-31         12
#
#    distinct_month
# 0              12
# 1               1
# 2              11
# 3               4
# 4              12

# %% [markdown]
# Similarly, we perform the recipient-month attribute aggregations. For recipient and month combination, number of services and number of distinct services are the same.
# The service usage for each recipient and each month is only a flag, indicating the use but not recording how many times within the month.

# %%
def get_recipient_month_attribute(df):
    recipient_month = df.groupby(['id', 'month']).agg(
        num_service = ('service', 'count'),
    ).reset_index()

    return recipient_month

# %%
recipient_month = get_recipient_month_attribute(df)
recipient_month.head()
# Out:
# /var/folders/99/6591xgpn4sq1ypfgnrzy_7n80000gn/T/ipykernel_27369/500739487.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   recipient_month = df.groupby(['id', 'month']).agg(
#   id     month  num_service
# 0  1     April            1
# 1  1    August            1
# 2  1  December            1
# 3  1  February            1
# 4  1   January            1

# %% [markdown]
# Now, we can merge the datasets in a sense so that some of the information about each person can carry over to the new datasets we've created. Specifically, we want to carry over gender, race, ethnicity, education level, and marital status.

# %%
#start with recipient
#we want to add columns of age, gender, race, ethnicity, education level, and marital status
#from the original dataset, making sure IDs match up and that there is only one occurrence of each ID.
recipient = pd.merge(recipient, df[['id', 'age', 'gender', 'race', 'ethnicity', 'marital', 'education','age_bin']], on='id', how='left')
#now remove duplicate rows
recipient = recipient.drop_duplicates(subset=['id'])
recipient.head()
# Out:
#    id  num_service  distinct_service first_date  last_date  num_month  \
# 0   1           12                 1 2021-01-31 2021-12-31         12
# 12  2            1                 1 2021-02-28 2021-02-28          1
# 13  3           11                 1 2021-02-28 2021-12-31         11
# 24  4            4                 1 2021-03-31 2021-12-31          4
# 28  5           12                 1 2021-01-31 2021-12-31         12
#
#     distinct_month   age    gender                      race  \
# 0               12  13.0    1~Male                99~Unknown
# 12               1  70.0  2~Female                   1~White
# 13              11  29.0  2~Female                   1~White
# 24               4   4.0  2~Female                   1~White
# 28              12  40.0    1~Male  2~Black/African American
#
#                 ethnicity                 marital  \
# 0   2~Not Hispanic/Latinx              99~Unknown
# 12  2~Not Hispanic/Latinx               2~Married
# 13  2~Not Hispanic/Latinx               2~Married
# 24  2~Not Hispanic/Latinx  1~Single-Never Married
# 28  2~Not Hispanic/Latinx               2~Married
#
#                                 education age_bin
# 0   GED~High School Diploma/GED Completed   10-19
# 12                             99~Unknown   70-79
# 13          9-12~High School (grade 9-12)   20-29
# 24          9-12~High School (grade 9-12)     0-9
# 28                 UNDERGRAD~Some College   40-49

# %%
#we'll do the same with recipient_month
recipient_month = pd.merge(recipient_month, df[['id', 'age', 'gender', 'race', 'ethnicity', 'marital', 'education','age_bin']], on='id', how='left')
#now remove rows that have duplicate ID-month pairs
recipient_month = recipient_month.drop_duplicates(subset=['id', 'month'])
recipient_month.head()
# Out:
#    id     month  num_service   age  gender        race              ethnicity  \
# 0   1     April            1  13.0  1~Male  99~Unknown  2~Not Hispanic/Latinx
# 12  1    August            1  13.0  1~Male  99~Unknown  2~Not Hispanic/Latinx
# 24  1  December            1  13.0  1~Male  99~Unknown  2~Not Hispanic/Latinx
# 36  1  February            1  13.0  1~Male  99~Unknown  2~Not Hispanic/Latinx
# 48  1   January            1  13.0  1~Male  99~Unknown  2~Not Hispanic/Latinx
#
#        marital                              education age_bin
# 0   99~Unknown  GED~High School Diploma/GED Completed   10-19
# 12  99~Unknown  GED~High School Diploma/GED Completed   10-19
# 24  99~Unknown  GED~High School Diploma/GED Completed   10-19
# 36  99~Unknown  GED~High School Diploma/GED Completed   10-19
# 48  99~Unknown  GED~High School Diploma/GED Completed   10-19

# %% [markdown]
# # Saving Data Transformations
# If you want to close your work and come back to it easily without having to rerun all of the above code, or if you want to use the same data in a new notebook, an easy workaround is to save the data to an intermediate file and then reload it. We'll be saving all of our datasets to files that we will then plot in the next section.

# %% [raw]
# #we will save df to a new csv file
# df.to_csv('dhs_cleaned.csv', index=False)
# recipient.to_csv('dhs_recipient.csv', index=False)
# recipient_month.to_csv('dhs_recipient_month.csv', index=False)

# %% [markdown]
# * the above cell is made into "raw" so it does not get to be run when we do "run all"

# %% [markdown]
# ## Looking at number of services

# %%
recipient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 533799 entries, 0 to 7116089
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                533799 non-null  category
#  1   num_service       533799 non-null  int64
#  2   distinct_service  533799 non-null  int64
#  3   first_date        533796 non-null  datetime64[ns]
#  4   last_date         533796 non-null  datetime64[ns]
#  5   num_month         533799 non-null  int64
#  6   distinct_month    533799 non-null  int64
#  7   age               533796 non-null  float64
#  8   gender            533796 non-null  category
#  9   race              533796 non-null  category
#  10  ethnicity         533796 non-null  object
#  11  marital           533796 non-null  category
#  12  education         533796 non-null  category
#  13  age_bin           533796 non-null  category
# dtypes: category(6), datetime64[ns](2), float64(1), int64(4), object(1)
# memory usage: 61.4+ MB

# %%
recipient.describe()
# Out:
#          num_service  distinct_service                     first_date  \
# count  533799.000000     533799.000000                         533796
# mean       13.331044          1.412423  2021-02-17 13:23:53.671289856
# min         0.000000          0.000000            2021-01-31 00:00:00
# 25%        12.000000          1.000000            2021-01-31 00:00:00
# 50%        12.000000          1.000000            2021-01-31 00:00:00
# 75%        12.000000          1.000000            2021-01-31 00:00:00
# max        89.000000         10.000000            2021-12-31 00:00:00
# std         8.146127          0.933249                            NaN
#
#                            last_date      num_month  distinct_month  \
# count                         533796  533799.000000   533799.000000
# mean   2021-12-24 00:59:53.282826752      13.331044       10.688772
# min              2021-01-31 00:00:00       0.000000        0.000000
# 25%              2021-12-31 00:00:00      12.000000       12.000000
# 50%              2021-12-31 00:00:00      12.000000       12.000000
# 75%              2021-12-31 00:00:00      12.000000       12.000000
# max              2021-12-31 00:00:00      89.000000       12.000000
# std                              NaN       8.146127        2.946890
#
#                  age
# count  533796.000000
# mean       32.402779
# min         0.000000
# 25%        13.000000
# 50%        29.000000
# 75%        49.000000
# max       109.000000
# std        23.189489

# %% [markdown]
# this says for most of recipients, the number of services is 12, and number of disctinct services is 1.
#
# but why do we have min as zero service? supposed the data file contains the usage of services, why would someone not using service and still in the data file? Recall we have removed recipients who are older than 110?

# %%
recipient[recipient.num_service == 0].id.to_list()
# Out:
# [25958, 85700, 473987]

# %%
recipient[recipient.num_service == 0]
# Out:
#              id  num_service  distinct_service first_date last_date  \
# 346207    25958            0                 0        NaT       NaT
# 1139955   85700            0                 0        NaT       NaT
# 6306687  473987            0                 0        NaT       NaT
#
#          num_month  distinct_month  age gender race ethnicity marital  \
# 346207           0               0  NaN    NaN  NaN       NaN     NaN
# 1139955          0               0  NaN    NaN  NaN       NaN     NaN
# 6306687          0               0  NaN    NaN  NaN       NaN     NaN
#
#         education age_bin
# 346207        NaN     NaN
# 1139955       NaN     NaN
# 6306687       NaN     NaN

# %%
# to verify, re-read the data file as orignal and check
check_list = recipient[recipient.num_service == 0].id.to_list()
df1 = pd.read_csv('dhs_service_records_synthesized_final.csv')
df1[df1.MCI_UNIQ_ID.isin(check_list)]
# Out:
#          synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT  \
# 1227119  SYNTHETIC DATA        25958      2021    01/31/2021
# 1227120  SYNTHETIC DATA        25958      2021    02/28/2021
# 1227121  SYNTHETIC DATA        25958      2021    03/31/2021
# 1227122  SYNTHETIC DATA        25958      2021    04/30/2021
# 1227123  SYNTHETIC DATA        25958      2021    05/31/2021
# 1227124  SYNTHETIC DATA        25958      2021    06/30/2021
# 1227125  SYNTHETIC DATA        25958      2021    07/31/2021
# 1227126  SYNTHETIC DATA        25958      2021    08/31/2021
# 1227127  SYNTHETIC DATA        25958      2021    09/30/2021
# 1227128  SYNTHETIC DATA        25958      2021    10/31/2021
# 1227129  SYNTHETIC DATA        25958      2021    11/30/2021
# 1227130  SYNTHETIC DATA        25958      2021    12/31/2021
# 6949798  SYNTHETIC DATA        85700      2021    01/31/2021
# 6949799  SYNTHETIC DATA        85700      2021    02/28/2021
# 6949800  SYNTHETIC DATA        85700      2021    03/31/2021
# 6949801  SYNTHETIC DATA        85700      2021    04/30/2021
# 6949802  SYNTHETIC DATA        85700      2021    05/31/2021
# 6949803  SYNTHETIC DATA        85700      2021    06/30/2021
# 6949804  SYNTHETIC DATA        85700      2021    07/31/2021
# 6949805  SYNTHETIC DATA        85700      2021    08/31/2021
# 6949806  SYNTHETIC DATA        85700      2021    09/30/2021
# 6949807  SYNTHETIC DATA        85700      2021    10/31/2021
# 6949808  SYNTHETIC DATA        85700      2021    11/30/2021
# 6949809  SYNTHETIC DATA        85700      2021    12/31/2021
# 7045696  SYNTHETIC DATA       473987      2021    01/31/2021
# 7045697  SYNTHETIC DATA       473987      2021    02/28/2021
# 7045698  SYNTHETIC DATA       473987      2021    03/31/2021
# 7045699  SYNTHETIC DATA       473987      2021    04/30/2021
# 7045700  SYNTHETIC DATA       473987      2021    05/31/2021
# 7045701  SYNTHETIC DATA       473987      2021    06/30/2021
# 7045702  SYNTHETIC DATA       473987      2021    07/31/2021
# 7045703  SYNTHETIC DATA       473987      2021    08/31/2021
# 7045704  SYNTHETIC DATA       473987      2021    09/30/2021
# 7045705  SYNTHETIC DATA       473987      2021    10/31/2021
# 7045706  SYNTHETIC DATA       473987      2021    11/30/2021
# 7045707  SYNTHETIC DATA       473987      2021    12/31/2021
#
#                                        service  GEO_AREA  age  DOB  DOD  \
# 1227119  Individuals_Receiving_Income_Supports       NaN  121  NaN  NaN
# 1227120  Individuals_Receiving_Income_Supports       NaN  121  NaN  NaN
# 1227121  Individuals_Receiving_Income_Supports       NaN  121  NaN  NaN
# 1227122  Individuals_Receiving_Income_Supports       NaN  121  NaN  NaN
# 1227123  Individuals_Receiving_Income_Supports       NaN  121  NaN  NaN
# 1227124  Individuals_Receiving_Income_Supports       NaN  121  NaN  NaN
# 1227125  Individuals_Receiving_Income_Supports       NaN  121  NaN  NaN
# 1227126  Individuals_Receiving_Income_Supports       NaN  121  NaN  NaN
# 1227127  Individuals_Receiving_Income_Supports       NaN  121  NaN  NaN
# 1227128  Individuals_Receiving_Income_Supports       NaN  121  NaN  NaN
# 1227129  Individuals_Receiving_Income_Supports       NaN  121  NaN  NaN
# 1227130  Individuals_Receiving_Income_Supports       NaN  121  NaN  NaN
# 6949798        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 6949799        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 6949800        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 6949801        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 6949802        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 6949803        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 6949804        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 6949805        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 6949806        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 6949807        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 6949808        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 6949809        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 7045696        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 7045697        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 7045698        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 7045699        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 7045700        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 7045701        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 7045702        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 7045703        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 7045704        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 7045705        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 7045706        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
# 7045707        Older_Adults_Receiving_Services       NaN  113  NaN  NaN
#
#          GENDER  GENDER_IDENTITY  SEX_ORIENT  LEGAL_SEX  \
# 1227119  1~Male              NaN         NaN        NaN
# 1227120  1~Male              NaN         NaN        NaN
# 1227121  1~Male              NaN         NaN        NaN
# 1227122  1~Male              NaN         NaN        NaN
# 1227123  1~Male              NaN         NaN        NaN
# 1227124  1~Male              NaN         NaN        NaN
# 1227125  1~Male              NaN         NaN        NaN
# 1227126  1~Male              NaN         NaN        NaN
# 1227127  1~Male              NaN         NaN        NaN
# 1227128  1~Male              NaN         NaN        NaN
# 1227129  1~Male              NaN         NaN        NaN
# 1227130  1~Male              NaN         NaN        NaN
# 6949798  1~Male              NaN         NaN        NaN
# 6949799  1~Male              NaN         NaN        NaN
# 6949800  1~Male              NaN         NaN        NaN
# 6949801  1~Male              NaN         NaN        NaN
# 6949802  1~Male              NaN         NaN        NaN
# 6949803  1~Male              NaN         NaN        NaN
# 6949804  1~Male              NaN         NaN        NaN
# 6949805  1~Male              NaN         NaN        NaN
# 6949806  1~Male              NaN         NaN        NaN
# 6949807  1~Male              NaN         NaN        NaN
# 6949808  1~Male              NaN         NaN        NaN
# 6949809  1~Male              NaN         NaN        NaN
# 7045696  1~Male              NaN         NaN        NaN
# 7045697  1~Male              NaN         NaN        NaN
# 7045698  1~Male              NaN         NaN        NaN
# 7045699  1~Male              NaN         NaN        NaN
# 7045700  1~Male              NaN         NaN        NaN
# 7045701  1~Male              NaN         NaN        NaN
# 7045702  1~Male              NaN         NaN        NaN
# 7045703  1~Male              NaN         NaN        NaN
# 7045704  1~Male              NaN         NaN        NaN
# 7045705  1~Male              NaN         NaN        NaN
# 7045706  1~Male              NaN         NaN        NaN
# 7045707  1~Male              NaN         NaN        NaN
#
#                              RACE              ETHNICITY  LIVING_ARRANGEMENT  \
# 1227119  2~Black/African American             99~Unknown                 NaN
# 1227120  2~Black/African American             99~Unknown                 NaN
# 1227121  2~Black/African American             99~Unknown                 NaN
# 1227122  2~Black/African American             99~Unknown                 NaN
# 1227123  2~Black/African American             99~Unknown                 NaN
# 1227124  2~Black/African American             99~Unknown                 NaN
# 1227125  2~Black/African American             99~Unknown                 NaN
# 1227126  2~Black/African American             99~Unknown                 NaN
# 1227127  2~Black/African American             99~Unknown                 NaN
# 1227128  2~Black/African American             99~Unknown                 NaN
# 1227129  2~Black/African American             99~Unknown                 NaN
# 1227130  2~Black/African American             99~Unknown                 NaN
# 6949798                   1~White  2~Not Hispanic/Latinx                 NaN
# 6949799                   1~White  2~Not Hispanic/Latinx                 NaN
# 6949800                   1~White  2~Not Hispanic/Latinx                 NaN
# 6949801                   1~White  2~Not Hispanic/Latinx                 NaN
# 6949802                   1~White  2~Not Hispanic/Latinx                 NaN
# 6949803                   1~White  2~Not Hispanic/Latinx                 NaN
# 6949804                   1~White  2~Not Hispanic/Latinx                 NaN
# 6949805                   1~White  2~Not Hispanic/Latinx                 NaN
# 6949806                   1~White  2~Not Hispanic/Latinx                 NaN
# 6949807                   1~White  2~Not Hispanic/Latinx                 NaN
# 6949808                   1~White  2~Not Hispanic/Latinx                 NaN
# 6949809                   1~White  2~Not Hispanic/Latinx                 NaN
# 7045696                   1~White  2~Not Hispanic/Latinx                 NaN
# 7045697                   1~White  2~Not Hispanic/Latinx                 NaN
# 7045698                   1~White  2~Not Hispanic/Latinx                 NaN
# 7045699                   1~White  2~Not Hispanic/Latinx                 NaN
# 7045700                   1~White  2~Not Hispanic/Latinx                 NaN
# 7045701                   1~White  2~Not Hispanic/Latinx                 NaN
# 7045702                   1~White  2~Not Hispanic/Latinx                 NaN
# 7045703                   1~White  2~Not Hispanic/Latinx                 NaN
# 7045704                   1~White  2~Not Hispanic/Latinx                 NaN
# 7045705                   1~White  2~Not Hispanic/Latinx                 NaN
# 7045706                   1~White  2~Not Hispanic/Latinx                 NaN
# 7045707                   1~White  2~Not Hispanic/Latinx                 NaN
#
#          EMPLOYMENT_STATUS          MARITAL_STATUS  \
# 1227119                NaN  1~Single-Never Married
# 1227120                NaN  1~Single-Never Married
# 1227121                NaN  1~Single-Never Married
# 1227122                NaN  1~Single-Never Married
# 1227123                NaN  1~Single-Never Married
# 1227124                NaN  1~Single-Never Married
# 1227125                NaN  1~Single-Never Married
# 1227126                NaN  1~Single-Never Married
# 1227127                NaN  1~Single-Never Married
# 1227128                NaN  1~Single-Never Married
# 1227129                NaN  1~Single-Never Married
# 1227130                NaN  1~Single-Never Married
# 6949798                NaN  1~Single-Never Married
# 6949799                NaN  1~Single-Never Married
# 6949800                NaN  1~Single-Never Married
# 6949801                NaN  1~Single-Never Married
# 6949802                NaN  1~Single-Never Married
# 6949803                NaN  1~Single-Never Married
# 6949804                NaN  1~Single-Never Married
# 6949805                NaN  1~Single-Never Married
# 6949806                NaN  1~Single-Never Married
# 6949807                NaN  1~Single-Never Married
# 6949808                NaN  1~Single-Never Married
# 6949809                NaN  1~Single-Never Married
# 7045696                NaN  1~Single-Never Married
# 7045697                NaN  1~Single-Never Married
# 7045698                NaN  1~Single-Never Married
# 7045699                NaN  1~Single-Never Married
# 7045700                NaN  1~Single-Never Married
# 7045701                NaN  1~Single-Never Married
# 7045702                NaN  1~Single-Never Married
# 7045703                NaN  1~Single-Never Married
# 7045704                NaN  1~Single-Never Married
# 7045705                NaN  1~Single-Never Married
# 7045706                NaN  1~Single-Never Married
# 7045707                NaN  1~Single-Never Married
#
#                        EDUCATION_LEVEL  VETERAN_FLAG
# 1227119  9-12~High School (grade 9-12)           NaN
# 1227120  9-12~High School (grade 9-12)           NaN
# 1227121  9-12~High School (grade 9-12)           NaN
# 1227122  9-12~High School (grade 9-12)           NaN
# 1227123  9-12~High School (grade 9-12)           NaN
# 1227124  9-12~High School (grade 9-12)           NaN
# 1227125  9-12~High School (grade 9-12)           NaN
# 1227126  9-12~High School (grade 9-12)           NaN
# 1227127  9-12~High School (grade 9-12)           NaN
# 1227128  9-12~High School (grade 9-12)           NaN
# 1227129  9-12~High School (grade 9-12)           NaN
# 1227130  9-12~High School (grade 9-12)           NaN
# 6949798  9-12~High School (grade 9-12)           NaN
# 6949799  9-12~High School (grade 9-12)           NaN
# 6949800  9-12~High School (grade 9-12)           NaN
# 6949801  9-12~High School (grade 9-12)           NaN
# 6949802  9-12~High School (grade 9-12)           NaN
# 6949803  9-12~High School (grade 9-12)           NaN
# 6949804  9-12~High School (grade 9-12)           NaN
# 6949805  9-12~High School (grade 9-12)           NaN
# 6949806  9-12~High School (grade 9-12)           NaN
# 6949807  9-12~High School (grade 9-12)           NaN
# 6949808  9-12~High School (grade 9-12)           NaN
# 6949809  9-12~High School (grade 9-12)           NaN
# 7045696  9-12~High School (grade 9-12)           NaN
# 7045697  9-12~High School (grade 9-12)           NaN
# 7045698  9-12~High School (grade 9-12)           NaN
# 7045699  9-12~High School (grade 9-12)           NaN
# 7045700  9-12~High School (grade 9-12)           NaN
# 7045701  9-12~High School (grade 9-12)           NaN
# 7045702  9-12~High School (grade 9-12)           NaN
# 7045703  9-12~High School (grade 9-12)           NaN
# 7045704  9-12~High School (grade 9-12)           NaN
# 7045705  9-12~High School (grade 9-12)           NaN
# 7045706  9-12~High School (grade 9-12)           NaN
# 7045707  9-12~High School (grade 9-12)           NaN

# %% [markdown]
# these are the three recipients that we removed during outlier removal, who have age greater than 110.
#
# Hence, we may consider making catgegory type change after removing outliers, the ID of the removed records will not make into the category label list.
#
# * alternatively, we can remove the unused categories when doing groupby

# %%
recipient.shape
# Out:
# (533799, 14)

# %%
recipient[recipient.distinct_service==0].shape
# Out:
# (3, 14)

# %%
recipient[recipient.distinct_service==1].shape
# Out:
# (424465, 14)

# %%
def get_recipient_attribute(df):
    recipient = df.groupby(df['id'].cat.remove_unused_categories()).agg(  ### remove unused categories 
        num_service = ('service', 'count'),
        distinct_service = ('service', 'nunique'), 
        first_date = ('date', 'min'), 
        last_date = ('date', 'max'), 
        num_month = ('month', 'count'), 
        distinct_month = ('month', 'nunique')
    ).reset_index()

    return recipient

# %%
recipient_new = get_recipient_attribute(df)
# Out:
# /var/folders/99/6591xgpn4sq1ypfgnrzy_7n80000gn/T/ipykernel_27369/312276210.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   recipient = df.groupby(df['id'].cat.remove_unused_categories()).agg(  ### remove unused categories

# %%
recipient_new.shape
# Out:
# (533796, 7)

# %% [markdown]
# * we see the ID size (number of rows) is reduced by 3, the outliers that were removed in earlier step.
#
# * based on my experience, not making the ID column as category type is the best in accordance with the need of having categorical variables. IDs are unique for an entity, in our case it is for the recipient. there is no real meaning that each ID is a category label. Therefore making ID as integer is appropriate.

# %% [markdown]
# ### Now, going back to inspect the number of services

# %%
import seaborn as sns
sns.displot(recipient, x="num_service")

# %% [markdown]
# this says many people may have similar number of services, maybe even same number of services, need to drill down.
#
# we can take a look at the distict services recipients use

# %%
sns.displot(recipient, x="distinct_service", hue = "gender", multiple="dodge")

# %% [markdown]
# Now we can see right away that overwhelming majority of recipients uses only one service in the entire year.

# %%
sns.displot(recipient, x="distinct_month", hue = "gender", multiple="dodge")

# %% [markdown]
# In-class work:
#
# - identify the top services by number of recipients
#      - you can choose to do by other measures (e.g., total usage months)
# - define a python function that computes characteristic attributes for services
#      - input: the service recipient event dataset
#      -  output: a data frame, with rows for services and columns for various attributes of the services
#      -  design your own attributes, see examples of attributes for recipients
# - create a new dataframe that hold attributes for services
#      - row keyed by service
#      - columns contain attributes that output by the function you created
# - experiment aggregation with or without reset_index() and see what happens
