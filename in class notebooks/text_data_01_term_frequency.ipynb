# %%
import pandas as pd
import numpy as np
import seaborn as sns 
from matplotlib import pyplot as plt
import matplotlib as mpl
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from langdetect import detect

# %% [raw]
# data_dir = "/Users/joshwinnes/Library/Mobile Documents/com~apple~CloudDocs/Wheaton College/fall 2024/topics in data science/data/"
# sdg_names = pd.read_excel(data_dir + "Digital Science SDG training set searches.xlsx")
# sdg_names = sdg_names.drop([0,1,2], axis=0)
# sdg_names = sdg_names.set_axis(["sdg", "sdg_name", "sdg_definition"],axis=1, copy=False)
# sdg_names.sdg_name.tolist()

# %% [markdown]
# ### helper functions for speeding up computation

# %%
def count_word(corpus):
    result = 0
    for x in corpus:
        result += len(x.split())
    return result
def count_zero(arr):
    zero_arr = np.zeros((arr.shape[0], arr.shape[1]))
    return np.sum(arr == zero_arr)

# %% [markdown]
# ### get data ready

# %% [markdown]
#  - language detection takes time, about 30 seconds on our dataset on my laptop
#  - may consider not doing language detection on large dataset unless really necessary
#  - may also consider running language detection after filtering by other dimensions
#  - in our dataset, there are 55 non-English excerpts, we will NOT remove them in our analysis
#  - this leaves our final analysis file with 26,526 excerpts in our corpus

# %%
data_dir = "/Users/joshwinnes/Library/Mobile Documents/com~apple~CloudDocs/Wheaton College/fall 2024/topics in data science/data/"
text_file_name = "osdg-community-data-v2024-04-01.csv"
text_df = pd.read_csv(data_dir + text_file_name,sep = "\t",  quotechar='"')
text_df.drop(text_df.columns.values[0],axis = 1, inplace=True)
text_df = text_df.query("agreement > 0.5 and (labels_positive - labels_negative) > 2").reset_index(drop=True)
text_df["lang"] = text_df["text"].apply(lambda x: detect(x))
text_df = text_df.query("lang == 'en'")
text_df.reset_index(inplace=True,drop=True)
text_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26471 entries, 0 to 26470
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   text_id          26471 non-null  object
#  1   text             26471 non-null  object
#  2   sdg              26471 non-null  int64
#  3   labels_negative  26471 non-null  int64
#  4   labels_positive  26471 non-null  int64
#  5   agreement        26471 non-null  float64
#  6   lang             26471 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# ### study term frequencies using scikit-learn vectorizer

# %%
corpus = text_df.text
count_vectorizer = CountVectorizer() # default is unigram, no stop word removal
count_vectorizer.fit(corpus)
count_vector = count_vectorizer.transform(corpus).toarray() 
print('vocabulary size: ' , len(count_vectorizer.vocabulary_))
print('vector shape: ', count_vector.shape)
print("proportion of non-zeros: ", 1-np.sum(count_vector==0)/(count_vector.shape[0]*count_vector.shape[1]))
# Out:
# vocabulary size:  46122
# vector shape:  (26471, 46122)
# proportion of non-zeros:  0.0014430694968051716

# %%
count_word(corpus), np.sum(count_vector), 1 - np.sum(count_vector)/count_word(corpus)
# Out:
# (2510738, 2493380, 0.00691350511283928)

# %% [markdown]
# notice the difference
# * the the total word count from string split and sum = 2,516,370
# * sum of all term counts, as counted from the sklearn tokenizer = 2,498,921
# * small difference (less than 1%), sperhaps due to certain processing details such as handling special characters?

# %% [markdown]
# Looking at results of vectorizer
#
# * count_vectorizer.vocabulary_ is a mapping of terms to feature indices , the key is the term in the corpus, the value is the index to the feature array
# * count_vectorizer.vocabulary_.keys() provides the list of the terms in the corpus
# * count_vectorizer.get_feature_names_out() is the corresponding array of the features
#
# * count_vectorizer.transform(corpus).toarray() provided the document-term frequency array: row for document in corpus, column for the terms in corpus

# %%
count_vectorizer.vocabulary_
# Out:
# {'from': 17379,
#  'gender': 17898,
#  'perspective': 31637,
#  'paulgaard': 31218,
#  'points': 32290,
#  'out': 30410,
#  'that': 41548,
#  'the': 41556,
#  'labour': 24073,
#  'markets': 26056,
#  'of': 29732,
#  'fishing': 16648,
#  'villages': 44507,
#  'have': 19327,
#  'been': 5464,
#  'highly': 19731,
#  'segregated': 37565,
#  'in': 21062,
#  'terms': 41417,
#  'existence': 15673,
#  'male': 25769,
#  'jobs': 22988,
#  'and': 3522,
#  'female': 16323,
#  'however': 20150,
#  'new': 28743,
#  'business': 6981,
#  'opportunities': 30093,
#  'led': 24518,
#  'to': 41964,
#  'population': 32484,
#  'peripheral': 31550,
#  'areas': 4097,
#  'now': 29303,
#  'working': 45577,
#  'service': 37809,
#  'industry': 21403,
#  'former': 17076,
#  'boys': 6471,
#  'girls': 18192,
#  'are': 4093,
#  'doing': 13175,
#  'same': 36911,
#  'indicates': 21299,
#  'change': 8049,
#  'because': 5433,
#  'traditional': 42264,
#  'boundaries': 6432,
#  'between': 5725,
#  'women': 45525,
#  'men': 26634,
#  'work': 45562,
#  'being': 5513,
#  'crossed': 10748,
#  'but': 6995,
#  'fact': 15971,
#  'young': 45896,
#  'people': 31465,
#  'still': 39780,
#  'represents': 35576,
#  'continuity': 9994,
#  'with': 45465,
#  'past': 31121,
#  '2002': 573,
#  '102': 121,
#  'when': 45246,
#  'refers': 34951,
#  'traditions': 42267,
#  'she': 38016,
#  'expectations': 15715,
#  'adults': 2547,
#  'participate': 31044,
#  'adult': 2541,
#  'culture': 10915,
#  'thus': 41780,
#  'these': 41656,
#  'traditionally': 42266,
#  'no': 28975,
#  'actual': 2356,
#  'youth': 45906,
#  'as': 4271,
#  'described': 12016,
#  'earlier': 13725,
#  '2015': 671,
#  'concludes': 9506,
#  'some': 38966,
#  'norway': 29230,
#  'school': 37220,
#  'is': 22546,
#  'foreign': 16999,
#  'time': 41856,
#  'waster': 44948,
#  'stealing': 39664,
#  'who': 45293,
#  'should': 38158,
#  'instead': 21824,
#  'spend': 39238,
#  'their': 41574,
#  'on': 29951,
#  'what': 45231,
#  'considered': 9768,
#  'be': 5400,
#  'real': 34516,
#  'average': 4825,
#  'figure': 16498,
#  'also': 3236,
#  'masks': 26141,
#  'large': 24259,
#  'differences': 12400,
#  'across': 2313,
#  'regions': 35095,
#  'kazakhstan': 23409,
#  'number': 29423,
#  'annual': 3648,
#  'contacts': 9904,
#  'ranges': 34297,
#  'astana': 4468,
#  'mangystau': 25883,
#  'parts': 31083,
#  'likely': 24901,
#  'very': 44361,
#  'limited': 24929,
#  'access': 2157,
#  'primary': 33103,
#  'care': 7394,
#  'addition': 2413,
#  'poor': 32445,
#  'coverage': 10513,
#  'outpatient': 30459,
#  'prescription': 32983,
#  'medicines': 26521,
#  'limits': 24934,
#  'both': 6399,
#  'effectiveness': 14053,
#  'appeal': 3863,
#  'at': 4504,
#  'phc': 31791,
#  'level': 24707,
#  'findings': 16569,
#  'consistent': 9780,
#  'previous': 33078,
#  'examined': 15549,
#  'wage': 44788,
#  'inequality': 21424,
#  'countries': 10450,
#  'blau': 6068,
#  'khan': 23548,
#  '2005': 582,
#  'fournier': 17169,
#  'koske': 23850,
#  '2012': 640,
#  'returns': 35930,
#  'education': 13995,
#  'found': 17152,
#  'an': 3452,
#  'important': 20996,
#  'role': 36382,
#  'explaining': 15768,
#  'rise': 36222,
#  'earnings': 13739,
#  'see': 37523,
#  'autor': 4794,
#  '2014': 661,
#  'magnitude': 25664,
#  'contribution': 10051,
#  'quite': 34078,
#  'small': 38687,
#  'two': 42879,
#  'types': 42891,
#  'explanation': 15770,
#  'commonly': 9182,
#  'proposed': 33504,
#  'literature': 25039,
#  'first': 16624,
#  'emphasises': 14448,
#  'relative': 35269,
#  'supply': 40519,
#  'demand': 11717,
#  'for': 16952,
#  'skills': 38556,
#  'characteristics': 8093,
#  'lower': 25361,
#  'net': 28691,
#  'get': 18058,
#  'higher': 19720,
#  'rewards': 36036,
#  'second': 37444,
#  'played': 32140,
#  'by': 7027,
#  'market': 26045,
#  'institutions': 21861,
#  'such': 40317,
#  'minimum': 27147,
#  'wages': 44793,
#  'degree': 11616,
#  'unionisation': 43491,
#  'rules': 36642,
#  'governing': 18477,
#  'bargaining': 5218,
#  'israel': 22627,
#  'oceanographic': 29671,
#  'limnological': 24936,
#  'research': 35649,
#  'station': 39615,
#  'monitors': 27598,
#  'quantity': 34010,
#  'quality': 33997,
#  'water': 44964,
#  'along': 3216,
#  'coastline': 8817,
#  'mediterranean': 26528,
#  'sea': 37372,
#  'nature': 28404,
#  'parks': 31006,
#  'authority': 4755,
#  'npa': 29312,
#  'rivers': 36263,
#  'behalf': 5489,
#  'moep': 27481,
#  'mekorot': 26585,
#  'local': 25148,
#  'authorities': 4754,
#  'monitor': 27592,
#  'drinking': 13438,
#  'under': 43165,
#  'supervision': 40501,
#  'ministry': 27158,
#  'health': 19414,
#  'effluent': 14067,
#  'prior': 33138,
#  'its': 22699,
#  'use': 43930,
#  'agricultural': 2830,
#  'sector': 37475,
#  'chapters': 8081,
#  'discussed': 12729,
#  'ways': 45010,
#  'make': 25734,
#  'food': 16926,
#  'systems': 40864,
#  'more': 27696,
#  'supportive': 40526,
#  'security': 37503,
#  'better': 5718,
#  'nutrition': 29471,
#  'sensitive': 37699,
#  'can': 7234,
#  'give': 18213,
#  'consumers': 9888,
#  'options': 30136,
#  'ultimately': 43001,
#  'it': 22649,
#  'choose': 8323,
#  'they': 41667,
#  'eat': 13768,
#  'influences': 21520,
#  'own': 30678,
#  'nutritional': 29472,
#  'outcomes': 30418,
#  'sends': 37674,
#  'signals': 38282,
#  'back': 4965,
#  'through': 41763,
#  'system': 40849,
#  'retailers': 35855,
#  'processors': 33250,
#  'producers': 33272,
#  'shape': 37970,
#  'produced': 33270,
#  'how': 20146,
#  'sustainably': 40652,
#  'war': 44884,
#  'terror': 41445,
#  'framework': 17229,
#  'international': 22112,
#  'law': 24362,
#  'helen': 19520,
#  'duffy': 13548,
#  'cambridge': 7194,
#  'university': 43540,
#  'press': 33019,
#  'pp': 32700,
#  'li': 24770,
#  '488': 1263,
#  'poses': 32542,
#  'increasingly': 21222,
#  'intractable': 22254,
#  'challenges': 8020,
#  'legal': 24542,
#  'order': 30164,
#  'commentators': 9140,
#  'query': 34041,
#  'whether': 45258,
#  'reaction': 34484,
#  '11': 148,
#  'might': 26987,
#  'relaxed': 35279,
#  'or': 30142,
#  'transformed': 42359,
#  'well': 45155,
#  'established': 15243,
#  'principles': 33128,
#  'particularly': 31058,
#  'fields': 16476,
#  'recourse': 34783,
#  'force': 16967,
#  'state': 39597,
#  'responsibility': 35777,
#  'other': 30366,
#  'scholars': 37211,
#  'opine': 30073,
#  'adequately': 2442,
#  'suited': 40377,
#  'address': 2421,
#  'relatively': 35270,
#  'polymorphous': 32412,
#  'threats': 41747,
#  'terrorism': 41446,
#  'regardless': 35055,
#  'one': 29966,
#  'stance': 39528,
#  'question': 34043,
#  'clear': 8637,
#  'current': 10960,
#  'has': 19269,
#  'generated': 17932,
#  'considerable': 9764,
#  'academic': 2119,
#  'writing': 45675,
#  'inside': 21758,
#  'outside': 30474,
#  'propelled': 33475,
#  'various': 44185,
#  'issues': 22640,
#  'application': 3892,
#  'human': 20249,
#  'rights': 36172,
#  'humanitarian': 20256,
#  'criminal': 10667,
#  'forefront': 16992,
#  'scholarly': 37210,
#  'inquiry': 21722,
#  'rates': 34359,
#  'appear': 3867,
#  'where': 45249,
#  'participation': 31048,
#  'there': 41627,
#  'possible': 32581,
#  'relationship': 35266,
#  'drug': 13475,
#  'disability': 12577,
#  'this': 41706,
#  'may': 26288,
#  'arise': 4142,
#  'after': 2713,
#  'definition': 11572,
#  'was': 44931,
#  'extended': 15843,
#  'include': 21161,
#  'chronic': 8366,
#  'conditions': 9557,
#  'krueger': 23930,
#  '2017': 698,
#  '47': 1244,
#  'around': 4185,
#  'fifth': 16484,
#  'non': 29031,
#  'participating': 31047,
#  'prime': 33105,
#  'age': 2741,
#  'males': 25774,
#  'were': 45180,
#  'regularly': 35140,
#  'taking': 40983,
#  'opioid': 30079,
#  'painkillers': 30800,
#  'contrast': 10031,
#  'share': 37977,
#  'households': 20131,
#  'man': 25829,
#  'remained': 35336,
#  'stable': 39472,
#  '76': 1595,
#  'over': 30503,
#  'most': 27761,
#  'panel': 30880,
#  'germany': 18037,
#  'nevertheless': 28741,
#  'witnessed': 45483,
#  'significant': 38293,
#  'decline': 11422,
#  'about': 2000,
#  '15': 274,
#  'percentage': 31488,
#  'employment': 14473,
#  'among': 3407,
#  'during': 13609,
#  'period': 31543,
#  'worker': 45570,
#  'spain': 39122,
#  'instance': 21810,
#  '1995': 535,
#  'only': 29987,
#  '22': 834,
#  '25': 883,
#  'had': 18992,
#  'woman': 45522,
#  'full': 17484,
#  'year': 45831,
#  'compared': 9258,
#  '42': 1184,
#  '52': 1319,
#  'crisis': 10689,
#  'dutch': 13620,
#  'weeks': 45111,
#  'per': 31479,
#  'though': 41733,
#  'not': 29238,
#  'hours': 20124,
#  'week': 45106,
#  'parents': 30983,
#  'pay': 31242,
#  'maximum': 26286,
#  'fee': 16279,
#  'kindergarten': 23646,
#  'total': 42135,
#  'costs': 10370,
#  '2011': 630,
#  'depending': 11889,
#  'public': 33743,
#  'private': 33174,
#  'counties': 10444,
#  'responsible': 35780,
#  'upper': 43813,
#  'secondary': 37447,
#  'which': 45261,
#  'finance': 16544,
#  'taxes': 41134,
#  'block': 6103,
#  'grants': 18567,
#  'vary': 44191,
#  'considerably': 9765,
#  'region': 35077,
#  'another': 3666,
#  'additional': 2414,
#  'subsidies': 40226,
#  'provisions': 33629,
#  'given': 18214,
#  'avoid': 4847,
#  'regional': 35081,
#  'disparities': 12827,
#  'kindergartens': 23647,
#  '50': 1294,
#  'all': 3122,
#  'financed': 16546,
#  'municipalities': 28081,
#  'abstract': 2035,
#  'paper': 30913,
#  'demonstrates': 11786,
#  'different': 12402,
#  'scientific': 37266,
#  'disciplines': 12657,
#  'successfully': 40306,
#  'merged': 26707,
#  'efficient': 14065,
#  'life': 24860,
#  'applications': 3893,
#  'we': 45045,
#  'propose': 33503,
#  'novel': 29291,
#  'approach': 3940,
#  'social': 38830,
#  'science': 37260,
#  'using': 43955,
#  'artificial': 4248,
#  'intelligence': 21965,
#  'suggesting': 40352,
#  'neural': 28717,
#  'network': 28701,
#  'designto': 12060,
#  'anticipate': 3721,
#  'predict': 32867,
#  'perceptions': 31494,
#  'regarding': 35054,
#  'cyprus': 11071,
#  'conflict': 9624,
#  'peace': 31307,
#  'mediation': 26500,
#  'process': 33245,
#  'our': 30404,
#  'model': 27413,
#  'based': 5283,
#  'associating': 4440,
#  'views': 44470,
#  'thoughts': 41736,
#  'critical': 10697,
#  'related': 35259,
#  'together': 41991,
#  'anticipation': 3725,
#  'securing': 37492,
#  'treaty': 42500,
#  '2020': 724,
#  'database': 11234,
#  'collected': 9000,
#  'completed': 9335,
#  'surveys': 40617,
#  'relations': 35265,
#  'department': 11869,
#  'students': 40045,
#  'near': 28526,
#  'east': 13759,
#  'obtained': 29625,
#  'digitally': 12446,
#  'coded': 8847,
#  'values': 44128,
#  'entire': 14818,
#  'associative': 4444,
#  'predicting': 32872,
#  'further': 17552,
#  'used': 43932,
#  'training': 42289,
#  'testing': 41479,
#  'certainly': 7904,
#  'waives': 44819,
#  'way': 45005,
#  'rare': 34338,
#  'area': 4094,
#  'those': 41732,
#  'individuals': 21352,
#  'pocket': 32265,
#  'expenses': 15737,
#  '78': 1613,
#  'income': 21179,
#  'rural': 36677,
#  'even': 15459,
#  'insurance': 21910,
#  'decade': 11347,
#  '2003': 576,
#  'visits': 44590,
#  'township': 42186,
#  'medical': 26506,
#  'centres': 7854,
#  'hospitals': 20086,
#  'falling': 16061,
#  'while': 45263,
#  'urban': 43857,
#  'similar': 38367,
#  'institution': 21847,
#  'did': 12369,
#  'exist': 15669,
#  'schemes': 37184,
#  'accompanied': 2185,
#  'strategy': 39920,
#  'orient': 30238,
#  'existing': 15676,
#  'create': 10612,
#  'community': 9224,
#  'neighbourhood': 28620,
#  'committee': 9171,
#  'alastair': 3021,
#  'wood': 45535,
#  'co': 8795,
#  'ordinated': 30179,
#  'production': 33278,
#  'maria': 26014,
#  'consolati': 9787,
#  'louis': 25342,
#  'scott': 37301,
#  'provided': 33608,
#  'invaluable': 22315,
#  'secretariat': 37461,
#  'assistance': 4427,
#  'example': 15556,
#  'majority': 25727,
#  'principally': 33120,
#  'dependent': 11887,
#  'agriculture': 2833,
#  'turn': 42808,
#  'society': 38850,
#  'farmers': 16127,
#  'managing': 25847,
#  'land': 24173,
#  'sustain': 40647,
#  'supplies': 40518,
#  'biodiversity': 5904,
#  'environmental': 14878,
#  'services': 37812,
#  'relationships': 35268,
#  'dynamic': 13671,
#  'intense': 21978,
#  'climate': 8681,
#  'rising': 36226,
#  'resource': 35739,
#  'scarcities': 37131,
#  'price': 33084,
#  'volatilities': 44681,
#  'put': 33889,
#  'them': 41580,
#  'pressure': 33025,
#  'present': 32988,
#  'case': 7503,
#  'lcoe': 24420,
#  'calculated': 7140,
#  'including': 21166,
#  'carbon': 7367,
#  'usd': 43916,
#  '30': 991,
#  'tonne': 42059,
#  'co2': 8796,
#  'advantage': 2555,
#  'nuclear': 29402,
#  'energy': 14645,
#  'context': 9959,
#  'cost': 10352,
#  'remains': 35338,
#  'light': 24880,
#  'changes': 8056,
#  'fuel': 17456,
#  'particular': 31054,
#  'protected': 33564,
#  'against': 2729,
#  'low': 25358,
#  'proportion': 33493,
#  'lifetime': 24873,
#  'power': 32682,
#  'generation': 17935,
#  'overnight': 30582,
#  'construction': 9851,
#  'contingency': 9979,
#  'exclude': 15596,
#  'idc': 20581,
#  'builds': 6850,
#  'nine': 28918,
#  'years': 45837,
#  'basic': 5295,
#  'six': 38507,
#  'three': 41748,
#  'junior': 23142,
#  'entering': 14803,
#  'senior': 37679,
#  'attend': 4606,
#  'either': 14150,
#  'academically': 2120,
#  'oriented': 30246,
#  'vocational': 44651,
#  'applies': 3897,
#  'islamic': 22591,
#  'formal': 17053,
#  'comprises': 9397,
#  'general': 17913,
#  'sekolah': 37592,
#  'menengah': 26644,
#  'atas': 4513,
#  'sma': 38683,
#  'kejuruan': 23455,
#  'smk': 38728,
#  'schools': 37226,
#  'madrasah': 25629,
#  'aliyah': 3115,
#  'ma': 25544,
#  'mak': 25731,
#  'chapter': 8078,
#  'concentrates': 9464,
#  'largely': 24260,
#  'provision': 33624,
#  'considers': 9770,
#  'side': 38244,
#  'develop': 12198,
#  'colleges': 9020,
#  'alternative': 3256,
#  'routes': 36524,
#  'introduction': 22289,
#  'structures': 40025,
#  'standard': 39532,
#  'reasonable': 34567,
#  'person': 31619,
#  'resultant': 35838,
#  'luck': 25429,
#  'liability': 24772,
#  'criminalizing': 10677,
#  'sm': 38682,
#  'disavowing': 12627,
#  'erotic': 15097,
#  'instantiating': 21817,
#  'violence': 44542,
#  'constitutionalism': 9825,
#  'crime': 10662,
#  'form': 17049,
#  'moral': 27675,
#  'judgment': 23093,
#  'euthanasia': 15421,
#  'assisted': 4430,
#  'suicide': 40365,
#  'abnormal': 1978,
#  'teratology': 41389,
#  'logic': 25210,
#  'criminalization': 10673,
#  'tensions': 41367,
#  'empirical': 14458,
#  'desert': 12035,
#  'changing': 8057,
#  'norms': 29210,
#  'rape': 34313,
#  'reform': 34993,
#  '10': 107,
#  'preparation': 32955,
#  'offences': 29746,
#  'interests': 22057,
#  'political': 32343,
#  'freedom': 17290,
#  'last': 24282,
#  'since': 38408,
#  '2010': 615,
#  'discharges': 12651,
#  'capita': 7318,
#  'tended': 41341,
#  'decrease': 11460,
#  'line': 24961,
#  'oecd': 29720,
#  'mentioned': 26671,
#  'previously': 33079,
#  'dwellers': 13644,
#  'represent': 35566,
#  '43': 1196,
#  '32': 1026,
#  'hospital': 20079,
#  'attendances': 4608,
#  'absence': 2014,
#  'information': 21545,
#  'determine': 12149,
#  'difference': 12398,
#  'populations': 32488,
#  'if': 20663,
#  'so': 38810,
#  'drivers': 13449,
#  'geographic': 17984,
#  'cultural': 10911,
#  'infrastructural': 21565,
#  'data': 11232,
#  'patient': 31175,
#  'would': 45635,
#  'aid': 2905,
#  'understanding': 43263,
#  'remedies': 35360,
#  'barriers': 5254,
#  'overall': 30507,
#  'available': 4811,
#  'socio': 38852,
#  'economic': 13874,
#  'play': 32138,
#  'reaching': 34480,
#  'gates': 17771,
#  'admitted': 2512,
#  'uneven': 43365,
#  'probably': 33211,
#  'stems': 39704,
#  'inability': 21065,
#  'facilities': 15964,
#  'provide': 33607,
#  'examines': 15553,
#  'effects': 14056,
#  'child': 8250,
#  'early': 13728,
#  'forced': 16969,
#  'marriages': 26087,
#  'cefm': 7775,
#  'within': 45477,
#  'commonwealth': 9188,
#  'specific': 39188,
#  'focus': 16856,
#  'africa': 2696,
#  'highlights': 19730,
#  'best': 5705,
#  'issue': 22638,
#  'national': 28363,
#  'judicial': 23099,
#  'processes': 33247,
#  'currently': 10961,
#  'place': 32057,
#  'african': 2697,
#  'kenya': 23495,
#  'rwanda': 36708,
#  'uganda': 42949,
#  'tanzania': 41056,
#  'then': 41589,
#  'followed': 16901,
#  'background': 4974,
#  'section': 37472,
#  'gives': 18217,
#  'historical': 19828,
#  'overview': 30655,
#  'global': 18264,
#  'respond': 35760,
#  'psv': 33689,
#  'encouraged': 14559,
#  'strong': 40010,
#  'links': 24991,
#  'enterprises': 14806,
#  'cover': 10512,
#  'remote': 35389,
#  'cater': 7597,
#  'less': 24673,
#  'affluent': 2666,
#  'analyses': 3479,
#  'impact': 20911,
#  'dual': 13516,
#  'universities': 43539,
#  'australia': 4730,
#  'short': 38137,
#  'cycle': 11050,
#  'scotland': 37299,
#  'sub': 40091,
#  'sectors': 37480,
#  'tertiary': 41453,
#  'emerging': 14398,
#  'italy': 22655,
#  'discusses': 12730,
#  'transition': 42382,
#  'collaboration': 8976,
#  'ofpost': 29806,
#  'analysis': 3481,
#  'policy': 32327,
#  'negative': 28584,
#  'effect': 14049,
#  'decentralization': 11383,
#  'implemented': 20971,
#  '2001': 570,
#  'corruption': 10330,
#  'too': 42070,
#  'become': 5441,
#  'decentrali': 11378,
#  'zed': 45983,
#  'especially': 15200,
#  'west': 45189,
#  'java': 22866,
#  'article': 4235,
#  'patterns': 31209,
#  'probable': 33210,
#  'causes': 7634,
#  'government': 18480,
#  'officials': 29772,
#  'solution': 38948,
#  'do': 13111,
#  'just': 23177,
#  'author': 4742,
#  'chose': 8334,
#  'ocio': 29678,
#  'depth': 11953,
#  'interview': 22214,
#  'main': 25690,
#  'orruption': 30296,
#  'mostly': 27764,
#  'took': 42071,
#  'budget': 6817,
#  'misappropriation': 27211,
#  'major': 25721,
#  'source': 39064,
#  'abuse': 2104,
#  'money': 27580,
#  'politics': 32361,
#  'tendency': 41344,
#  'misuse': 27297,
#  'loopholes': 25289,
#  'regulations': 35146,
#  'enforcement': 14658,
#  'therefore': 41633,
#  'betterment': 5719,
#  'regulation': 35145,
#  'organizational': 30225,
#  'structure': 40023,
#  'officers': 29767,
#  'unequal': 43355,
#  'like': 24897,
#  'south': 39075,
#  'brazil': 6551,
#  'proportions': 33499,
#  'believe': 5541,
#  'incomes': 21181,
#  'made': 25621,
#  'equal': 14982,
#  'shift': 38069,
#  'preferences': 32905,
#  'towards': 42176,
#  'redistribution': 34883,
#  'brics': 6635,
#  'shown': 38175,
#  '12': 181,
#  'forthcoming': 17113,
#  'few': 16425,
#  'late': 24292,
#  '1980s': 510,
#  'course': 10482,
#  'view': 44465,
#  'says': 37090,
#  'little': 25063,
#  'preferred': 32908,
#  'method': 26797,
#  'achieving': 2269,
#  'attitudes': 4632,
#  'translate': 42393,
#  'into': 22244,
#  'concrete': 9520,
#  'tax': 41127,
#  'transfer': 42341,
#  'part': 31032,
#  'contract': 10005,
#  'every': 15478,
#  'country': 10459,
#  'stigma': 39769,
#  'attached': 4581,
#  'welfare': 45152,
#  'recipients': 34683,
#  'increases': 21219,
#  'disadvantage': 12581,
#  'similarly': 38371,
#  'dignity': 12458,
#  'recognition': 34713,
#  'wrongs': 45687,
#  'cause': 7632,
#  '54': 1339,
#  'undervaluing': 43291,
#  'wrong': 45681,
#  'directly': 12556,
#  'hence': 19565,
#  'right': 36167,
#  'value': 44125,
#  'synthesis': 40828,
#  'dimensions': 12490,
#  'equality': 14990,
#  'redressing': 34894,
#  'addressing': 2425,
#  'stereotyping': 39729,
#  'step': 39710,
#  'taken': 40974,
#  'cescr': 7924,
#  'cedaw': 7754,
#  'reporting': 35557,
#  'guidelines': 18855,
#  'para': 30930,
#  '29': 945,
#  'ecuador': 13926,
#  'op': 30018,
#  'bandung': 5145,
#  'city': 8514,
#  '44': 1209,
#  'revenue': 35960,
#  '2016': 683,
#  'expected': 15716,
#  'come': 9093,
#  'transfers': 42349,
#  'common': 9179,
#  'problem': 33219,
#  'ith': 22675,
#  'automatic': 4779,
#  'allocation': 3168,
#  'fund': 17509,
#  'partly': 31072,
#  'allocated': 3165,
#  'registered': 35100,
#  'governments': 18485,
#  'does': 13157,
#  'take': 40970,
#  'account': 2205,
#  'unregistered': 43646,
#  'high': 19719,
#  'much': 27941,
#  'true': 42665,
#  'damage': 11148,
#  'aftermath': 2716,
#  'disasters': 12623,
#  'undocumented': 43320,
#  'needs': 28570,
#  'explored': 15791,
#  'vulnerability': 44753,
#  'island': 22597,
#  'states': 39608,
#  'retreat': 35896,
#  'threat': 41742,
#  'option': 30133,
#  'risk': 36227,
#  'left': 24536,
#  'unattended': 43063,
#  'amount': 3415,
#  '70': 1532,
#  'cent': 7822,
#  'death': 11326,
#  'toll': 42020,
#  'arises': 4144,
#  'destruction': 12105,
#  'infrastructure': 21566,
#  'disruption': 12895,
#  'staff': 39485,
#  'discover': 12700,
#  'vital': 44605,
#  'elements': 14242,
#  'damaged': 11149,
#  'destroyed': 12102,
#  'beyond': 5740,
#  'effective': 14051,
#  'operational': 30044,
#  ...}

# %%
count_vectorizer.vocabulary_.items()
# Out:
# dict_items([('from', 17379), ('gender', 17898), ('perspective', 31637), ('paulgaard', 31218), ('points', 32290), ('out', 30410), ('that', 41548), ('the', 41556), ('labour', 24073), ('markets', 26056), ('of', 29732), ('fishing', 16648), ('villages', 44507), ('have', 19327), ('been', 5464), ('highly', 19731), ('segregated', 37565), ('in', 21062), ('terms', 41417), ('existence', 15673), ('male', 25769), ('jobs', 22988), ('and', 3522), ('female', 16323), ('however', 20150), ('new', 28743), ('business', 6981), ('opportunities', 30093), ('led', 24518), ('to', 41964), ('population', 32484), ('peripheral', 31550), ('areas', 4097), ('now', 29303), ('working', 45577), ('service', 37809), ('industry', 21403), ('former', 17076), ('boys', 6471), ('girls', 18192), ('are', 4093), ('doing', 13175), ('same', 36911), ('indicates', 21299), ('change', 8049), ('because', 5433), ('traditional', 42264), ('boundaries', 6432), ('between', 5725), ('women', 45525), ('men', 26634), ('work', 45562), ('being', 5513), ('crossed', 10748), ('but', 6995), ('fact', 15971), ('young', 45896), ('people', 31465), ('still', 39780), ('represents', 35576), ('continuity', 9994), ('with', 45465), ('past', 31121), ('2002', 573), ('102', 121), ('when', 45246), ('refers', 34951), ('traditions', 42267), ('she', 38016), ('expectations', 15715), ('adults', 2547), ('participate', 31044), ('adult', 2541), ('culture', 10915), ('thus', 41780), ('these', 41656), ('traditionally', 42266), ('no', 28975), ('actual', 2356), ('youth', 45906), ('as', 4271), ('described', 12016), ('earlier', 13725), ('2015', 671), ('concludes', 9506), ('some', 38966), ('norway', 29230), ('school', 37220), ('is', 22546), ('foreign', 16999), ('time', 41856), ('waster', 44948), ('stealing', 39664), ('who', 45293), ('should', 38158), ('instead', 21824), ('spend', 39238), ('their', 41574), ('on', 29951), ('what', 45231), ('considered', 9768), ('be', 5400), ('real', 34516), ('average', 4825), ('figure', 16498), ('also', 3236), ('masks', 26141), ('large', 24259), ('differences', 12400), ('across', 2313), ('regions', 35095), ('kazakhstan', 23409), ('number', 29423), ('annual', 3648), ('contacts', 9904), ('ranges', 34297), ('astana', 4468), ('mangystau', 25883), ('parts', 31083), ('likely', 24901), ('very', 44361), ('limited', 24929), ('access', 2157), ('primary', 33103), ('care', 7394), ('addition', 2413), ('poor', 32445), ('coverage', 10513), ('outpatient', 30459), ('prescription', 32983), ('medicines', 26521), ('limits', 24934), ('both', 6399), ('effectiveness', 14053), ('appeal', 3863), ('at', 4504), ('phc', 31791), ('level', 24707), ('findings', 16569), ('consistent', 9780), ('previous', 33078), ('examined', 15549), ('wage', 44788), ('inequality', 21424), ('countries', 10450), ('blau', 6068), ('khan', 23548), ('2005', 582), ('fournier', 17169), ('koske', 23850), ('2012', 640), ('returns', 35930), ('education', 13995), ('found', 17152), ('an', 3452), ('important', 20996), ('role', 36382), ('explaining', 15768), ('rise', 36222), ('earnings', 13739), ('see', 37523), ('autor', 4794), ('2014', 661), ('magnitude', 25664), ('contribution', 10051), ('quite', 34078), ('small', 38687), ('two', 42879), ('types', 42891), ('explanation', 15770), ('commonly', 9182), ('proposed', 33504), ('literature', 25039), ('first', 16624), ('emphasises', 14448), ('relative', 35269), ('supply', 40519), ('demand', 11717), ('for', 16952), ('skills', 38556), ('characteristics', 8093), ('lower', 25361), ('net', 28691), ('get', 18058), ('higher', 19720), ('rewards', 36036), ('second', 37444), ('played', 32140), ('by', 7027), ('market', 26045), ('institutions', 21861), ('such', 40317), ('minimum', 27147), ('wages', 44793), ('degree', 11616), ('unionisation', 43491), ('rules', 36642), ('governing', 18477), ('bargaining', 5218), ('israel', 22627), ('oceanographic', 29671), ('limnological', 24936), ('research', 35649), ('station', 39615), ('monitors', 27598), ('quantity', 34010), ('quality', 33997), ('water', 44964), ('along', 3216), ('coastlin ...

# %%
count_vectorizer.vocabulary_.keys()
# Out:
# dict_keys(['from', 'gender', 'perspective', 'paulgaard', 'points', 'out', 'that', 'the', 'labour', 'markets', 'of', 'fishing', 'villages', 'have', 'been', 'highly', 'segregated', 'in', 'terms', 'existence', 'male', 'jobs', 'and', 'female', 'however', 'new', 'business', 'opportunities', 'led', 'to', 'population', 'peripheral', 'areas', 'now', 'working', 'service', 'industry', 'former', 'boys', 'girls', 'are', 'doing', 'same', 'indicates', 'change', 'because', 'traditional', 'boundaries', 'between', 'women', 'men', 'work', 'being', 'crossed', 'but', 'fact', 'young', 'people', 'still', 'represents', 'continuity', 'with', 'past', '2002', '102', 'when', 'refers', 'traditions', 'she', 'expectations', 'adults', 'participate', 'adult', 'culture', 'thus', 'these', 'traditionally', 'no', 'actual', 'youth', 'as', 'described', 'earlier', '2015', 'concludes', 'some', 'norway', 'school', 'is', 'foreign', 'time', 'waster', 'stealing', 'who', 'should', 'instead', 'spend', 'their', 'on', 'what', 'considered', 'be', 'real', 'average', 'figure', 'also', 'masks', 'large', 'differences', 'across', 'regions', 'kazakhstan', 'number', 'annual', 'contacts', 'ranges', 'astana', 'mangystau', 'parts', 'likely', 'very', 'limited', 'access', 'primary', 'care', 'addition', 'poor', 'coverage', 'outpatient', 'prescription', 'medicines', 'limits', 'both', 'effectiveness', 'appeal', 'at', 'phc', 'level', 'findings', 'consistent', 'previous', 'examined', 'wage', 'inequality', 'countries', 'blau', 'khan', '2005', 'fournier', 'koske', '2012', 'returns', 'education', 'found', 'an', 'important', 'role', 'explaining', 'rise', 'earnings', 'see', 'autor', '2014', 'magnitude', 'contribution', 'quite', 'small', 'two', 'types', 'explanation', 'commonly', 'proposed', 'literature', 'first', 'emphasises', 'relative', 'supply', 'demand', 'for', 'skills', 'characteristics', 'lower', 'net', 'get', 'higher', 'rewards', 'second', 'played', 'by', 'market', 'institutions', 'such', 'minimum', 'wages', 'degree', 'unionisation', 'rules', 'governing', 'bargaining', 'israel', 'oceanographic', 'limnological', 'research', 'station', 'monitors', 'quantity', 'quality', 'water', 'along', 'coastline', 'mediterranean', 'sea', 'nature', 'parks', 'authority', 'npa', 'rivers', 'behalf', 'moep', 'mekorot', 'local', 'authorities', 'monitor', 'drinking', 'under', 'supervision', 'ministry', 'health', 'effluent', 'prior', 'its', 'use', 'agricultural', 'sector', 'chapters', 'discussed', 'ways', 'make', 'food', 'systems', 'more', 'supportive', 'security', 'better', 'nutrition', 'sensitive', 'can', 'give', 'consumers', 'options', 'ultimately', 'it', 'choose', 'they', 'eat', 'influences', 'own', 'nutritional', 'outcomes', 'sends', 'signals', 'back', 'through', 'system', 'retailers', 'processors', 'producers', 'shape', 'produced', 'how', 'sustainably', 'war', 'terror', 'framework', 'international', 'law', 'helen', 'duffy', 'cambridge', 'university', 'press', 'pp', 'li', '488', 'poses', 'increasingly', 'intractable', 'challenges', 'legal', 'order', 'commentators', 'query', 'whether', 'reaction', '11', 'might', 'relaxed', 'or', 'transformed', 'well', 'established', 'principles', 'particularly', 'fields', 'recourse', 'force', 'state', 'responsibility', 'other', 'scholars', 'opine', 'adequately', 'suited', 'address', 'relatively', 'polymorphous', 'threats', 'terrorism', 'regardless', 'one', 'stance', 'question', 'clear', 'current', 'has', 'generated', 'considerable', 'academic', 'writing', 'inside', 'outside', 'propelled', 'various', 'issues', 'application', 'human', 'rights', 'humanitarian', 'criminal', 'forefront', 'scholarly', 'inquiry', 'rates', 'appear', 'where', 'participation', 'there', 'possible', 'relationship', 'drug', 'disability', 'this', 'may', 'arise', 'after', 'definition', 'was', 'extended', 'include', 'chronic', 'conditions', 'krueger', '2017', '47', 'around', 'fifth', 'non', 'participating', 'prime', 'age', 'males', 'were', 'regularly', 'taking', 'opioid', 'painkillers', 'contrast', 'share',  ...

# %%
count_vectorizer.get_feature_names_out()
# Out:
# array(['00', '000', '0000002', ..., 'œopen', 'ʿadawiyya', '四个全面'],
#       dtype=object)

# %% [markdown]
# ### Stop word removal

# %%
corpus = text_df.text
count_vectorizer = CountVectorizer(ngram_range=(1,1),stop_words='english') 
count_vectorizer.fit(corpus) 
count_vector = count_vectorizer.transform(corpus).toarray() 
print('vocabulary size: ' , len(count_vectorizer.vocabulary_))
print('vector shape: ', count_vector.shape)
print("proportion of non-zeros: ", 1-np.sum(count_vector==0)/(count_vector.shape[0]*count_vector.shape[1]))
# Out:
# vocabulary size:  45823
# vector shape:  (26471, 45823)
# proportion of non-zeros:  0.0009974833621272383

# %% [markdown]
# Notice the difference in vocabular size between the results of stop-word removal vs. non removal.

# %% [markdown]
# We can see what was used (and removed) as stop words in the documents.

# %%
count_vectorizer.get_stop_words()
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
#            'behind',
#            'being',
#            'below',
#            'beside',
#            'besides',
#            'between',
#            'beyond',
#            'bill',
#            'both',
#            'bottom',
#            'but',
#            'by',
#            'call',
#            'can',
#            'cannot',
#            'cant',
#            'co',
#            'con',
#            'could',
#            'couldnt',
#            'cry',
#            'de',
#            'describe',
#            'detail',
#            'do',
#            'done',
#            'down',
#            'due',
#            'during',
#            'each',
#            'eg',
#            'eight',
#            'either',
#            'eleven',
#            'else',
#            'elsewhere',
#            'empty',
#            'enough',
#            'etc',
#            'even',
#            'ever',
#            'every',
#            'everyone',
#            'everything',
#            'everywhere',
#            'except',
#            'few',
#            'fifteen',
#            'fifty',
#            'fill',
#            'find',
#            'fire',
#            'first',
#            'five',
#            'for',
#            'former',
#            'formerly',
#            'forty',
#            'found',
#            'four',
#            'from',
#            'front',
#            'full',
#            'further',
#            'get',
#            'give',
#            'go',
#            'had',
#            'has',
#            'hasnt',
#            'have',
#            'he',
#            'hence',
#            'her',
#            'here',
#            'hereafter',
#            'hereby',
#            'herein',
#            'hereupon',
#            'hers',
#            'herself',
#            'him',
#            'himself',
#            'his',
#            'how',
#            'however',
#            'hundred',
#            'i',
#            'ie',
#            'if',
#            'in',
#            'inc',
#            'indeed',
#            'interest',
#            'into',
#            'is',
#            'it',
#            'its',
#            'itself',
#            'keep',
#            'last',
#            'latter',
#            'latterly',
#            'least',
#            'less',
#            'ltd',
#            'made',
#            'many',
#            'may',
#            'me',
#            'meanwhile',
#            'might',
#            'mill',
#            'mine',
#            'more',
#            'moreover',
#            'most',
#            'mostly',
#            'move',
#            'much',
#            'must',
#            'my',
#            'myself',
#            'name',
#            'namely',
#            'neither',
#            'never',
#            'nevertheless',
#            'next',
#            'nine',
#            'no',
#            'nobody',
#            'none',
#            'noone',
#            'nor',
#            'not',
#            'nothing',
#            'now',
#            'nowhere',
#            'of',
#            'off',
#            'often',
#            'on',
#            'once',
#            'one',
#            'only',
#            'onto',
#            'or',
#            'other',
#            'others',
#            'otherwise',
#            'our',
#            'ours',
#            'ourselves',
#            'out',
#            'over',
#            'own',
#            'part',
#            'per',
#            'perhaps',
#            'please',
#            'put',
#            'rather',
#            're',
#            'same',
#            'see',
#            'seem',
#            'seemed',
#            'seeming',
#            'seems',
#            'serious',
#            'several',
#            'she',
#            'should',
#            'show',
#            'side',
#            'since',
#            'sincere',
#            'six',
#            'sixty',
#            'so',
#            'some',
#            'somehow',
#            'someone',
#            'something',
#            'sometime',
#            'sometimes',
#            'somewhere',
#            'still',
#            'such',
#            'system',
#            'take',
#            'ten',
#            'than',
#            'that',
#            'the',
#            'their',
#            'them',
#            'themselves',
#            'then',
#            'thence',
#            'there',
#            'thereafter',
#            'thereby',
#            'therefore',
#            'therein',
#            'thereupon',
#            'these',
#            'they',
#            'thick',
#            'thin',
#            'third',
#            'this',
#            'those',
#            'though',
#            'three',
#            'through',
#            'throughout',
#            'thru',
#            'thus',
#            'to',
#            'together',
#            'too',
#            'top',
#            'toward',
#            'towards',
#            'twelve',
#            'twenty',
#            'two',
#            'un',
#            'under',
#            'until',
#            'up',
#            'upon',
#            'us',
#            'very',
#            'via',
#            'was',
#            'we',
#            'well',
#            'were',
#            'what',
#            'whatever',
#            'when',
#            'whence',
#            'whenever',
#            'where',
#            'whereafter',
#            'whereas',
#            'whereby',
#            'wherein',
#            'whereupon',
#            'wherever',
#            'whether',
#            'which',
#            'while',
#            'whither',
#            'who',
#            'whoever',
#            'whole',
#            'whom',
#            'whose',
#            'why',
#            'will',
#            'with',
#            'within',
#            'without',
#            'would',
#            'yet',
#            'you',
#            'your',
#            'yours',
#            'yourself',
#            'yourselves'})

# %% [markdown]
#  - take the document-term matrix (count vectorized array), make into a pandas dataframe with feature names (terms) as column names

# %%
corpus = text_df.text
count_vectorizer = CountVectorizer(stop_words='english')
count_vectorizer.fit(corpus)
count_vector = count_vectorizer.transform(corpus).toarray() 
count_vector_df = pd.DataFrame(count_vector, columns=count_vectorizer.get_feature_names_out())

# %% [markdown]
# we can obtain term frequency (across entire corpus) from the document-term dataframe, by summing across rows for each term (feature, column)

# %%
term_freq = pd.DataFrame({"term": count_vector_df.columns.values, "freq" : count_vector_df.sum(axis=0)})
term_freq.sort_values(by="freq", ascending=False)
# Out:
#                     term  freq
# countries      countries  8493
# women              women  6017
# development  development  5889
# public            public  4819
# social            social  4754
# ...                  ...   ...
# escarpment    escarpment     1
# escherichia  escherichia     1
# painelbio      painelbio     1
# paim                paim     1
# joules            joules     1
#
# [45823 rows x 2 columns]

# %% [markdown]
#  - take a look at a portion of the term-document matrix

# %%
count_vector_df.loc[100:125,term_freq.sort_values(by="freq", ascending =False)[:20].term] # take a portion
# Out:
#      countries  women  development  public  social  health  water  education  \
# 100          0      0            0       0       0       0      0          0
# 101          0      0            0       0       1       0      0          1
# 102          1      0            0       0       0       0      0          0
# 103          0      0            0       0       0       0      0          2
# 104          0      0            0       0       0       0      0          0
# 105          0      0            0       0       0       0      0          0
# 106          1      0            0       2       0       0      0          0
# 107          2      0            0       0       0       0      0          0
# 108          0      0            0       0       0       0      0          1
# 109          0      0            0       0       0       0      0          0
# 110          3      0            0       0       0       0      0          0
# 111          1      3            0       0       1       0      0          0
# 112          0      0            0       1       0       0      0          0
# 113          0      0            0       0       0       0      0          0
# 114          1      0            0       0       0       0      0          0
# 115          0      0            0       0       0       0      0          0
# 116          0      0            0       1       0       0      0          0
# 117          0      0            4       0       0       0      0          0
# 118          2      0            0       0       0       0      0          0
# 119          0      0            0       0       0       1      0          0
# 120          0      0            0       0       0       1      0          0
# 121          0      0            0       0       0       0      0          0
# 122          0      0            2       0       0       0      0          0
# 123          0      0            0       0       0       0      0          0
# 124          2      0            0       0       1       0      0          0
# 125          0      4            4       0       1       1      0          0
#
#      policy  international  national  energy  law  rights  economic  oecd  \
# 100       0              0         0       0    0       0         0     0
# 101       0              0         0       0    0       0         1     0
# 102       0              0         0       0    0       0         0     0
# 103       0              0         0       0    0       0         0     0
# 104       0              0         0       0    0       0         0     0
# 105       0              0         0       0    0       0         0     0
# 106       0              1         1       0    0       0         0     0
# 107       0              0         0       1    0       0         1     1
# 108       0              0         0       0    0       0         0     0
# 109       0              0         1       0    0       0         0     0
# 110       1              0         0       0    0       0         0     0
# 111       0              0         0       0    0       0         0     1
# 112       0              0         0       0    0       1         0     0
# 113       0              0         1       0    0       0         1     0
# 114       0              0         0       0    0       0         0     2
# 115       0              0         0       2    0       0         1     0
# 116       0              3         1       0    2       4         0     0
# 117       0              1         0       0    0       0         0     0
# 118       0              0         0       0    0       0         0     2
# 119       0              0         0       0    0       0         0     0
# 120       0              0         0       0    0       0         0     0
# 121       0              0         0       1    0       0         0     0
# 122       1              0         2       0    0       0         0     0
# 123       0              0         0       0    0       0         0     0
# 124       0              0         0       0    0       0         0     0
# 125       0              0         0       0    0       1         2     0
#
#      use  income  new  level
# 100    0       0    0      0
# 101    0       0    0      0
# 102    0       0    0      0
# 103    0       0    0      1
# 104    0       2    0      0
# 105    0       0    1      0
# 106    0       0    0      1
# 107    0       0    0      0
# 108    0       0    0      0
# 109    0       0    0      0
# 110    0       2    0      0
# 111    0       2    0      0
# 112    0       0    0      0
# 113    0       0    0      0
# 114    0       0    0      0
# 115    1       0    0      0
# 116    0       0    0      0
# 117    0       0    0      0
# 118    0       0    0      0
# 119    0       0    0      0
# 120    0       0    0      0
# 121    0       0    0      0
# 122    0       0    0      0
# 123    2       0    1      0
# 124    0       0    1      0
# 125    0       0    1      0

# %%
total_word_count = count_word(corpus) 
total_word_count, term_freq.freq.sum(), (1-term_freq.freq.sum()/total_word_count)
# Out:
# (2510738, 1440843, 0.42612769631877156)

# %% [markdown]
#  - stop word removal reduced document word frequency count by 40%

# %% [markdown]
# ### bi-grams

# %%
corpus = text_df.text
count_vectorizer = CountVectorizer(ngram_range=(2,2), stop_words='english') 
count_vectorizer.fit(corpus)
count_vector = count_vectorizer.transform(corpus).toarray() 
print('vocabulary size: ' , len(count_vectorizer.vocabulary_))
print('vector shape: ', count_vector.shape)
# array count_vector is much bigger, counting zeros tends to crash the kernel, so we should skip it.
# print("proportion of non-zeros: ", 1-count_zero(count_vector)/(count_vector.shape[0]*count_vector.shape[1]))
# Out:
# vocabulary size:  877716
# vector shape:  (26471, 877716)

# %% [markdown]
# ### tri-grams

# %% [raw]
# corpus = text_df.text
# count_vectorizer = CountVectorizer(ngram_range=(3,3), stop_words='english')
# count_vectorizer.fit(corpus)
# count_vector = count_vectorizer.transform(corpus).toarray()
# print('vocabulary size: ' , len(count_vectorizer.vocabulary_))
# print('vector shape: ', count_vector.shape)
# # array count_vector is much bigger, counting zeros tends to crash the kernel, so we should skip it.
# # print("proportion of non-zeros: ", 1-np.sum(count_vector==0)/(count_vector.shape[0]*count_vector.shape[1]))

# %% [markdown]
# Notice that the vocabulary sizes increases by big proportion when we go from unigram, to bigram, to trigram
#
# we can specify the minimum size of document frequency, min_df, so that only the terms appearing in minimum number of min_df documents in the corpus would be considered for vocabulary

# %% [markdown]
# ### Term frequency with minimum document frequency

# %%
# the lass line in this cell that calls for count_vector_df.sum will not finish 
# unless min_df is set to 2 or above in the CountVectorizer call at top of this cell, make sure to specify
count_vectorizer = CountVectorizer(ngram_range = (2,2),stop_words='english', min_df=5)
count_vectorizer.fit(corpus)
count_vector = count_vectorizer.transform(corpus).toarray() 
print('vocabulary size: ' , len(count_vectorizer.vocabulary_))
print('vector shape: ', count_vector.shape)
count_vector_df = pd.DataFrame(count_vector, columns=count_vectorizer.get_feature_names_out())
bigram_freq = pd.DataFrame({"term": count_vector_df.columns.values, "freq" : count_vector_df.sum(axis=0)})
# Out:
# vocabulary size:  28393
# vector shape:  (26471, 28393)

# %% [markdown]
# Notice the vocabulary size dropped from 881392 to 28447

# %% [markdown]
# How do we verify that term frequency computed in such a sequence of multiple operations (stop word removal, min_frequency, multiple aggregations) is correct?

# %%
bigram_freq.query("term == 'rural areas'")
# Out:
#                     term  freq
# rural areas  rural areas   441

# %%
print("vocabulary term and frequency: ", bigram_freq.query("term == 'rural areas'")["freq"])
print("vocabulary index is: ", count_vectorizer.vocabulary_.get("rural areas"))
print("vocabulary index is: ", count_vectorizer.vocabulary_[u'rural areas'])# u'string' for unicode string 'string'
print("vocabulary index is: ", count_vectorizer.vocabulary_.get(u'rural areas') )
# Out:
# vocabulary term and frequency:  rural areas    441
# Name: freq, dtype: int64
# vocabulary index is:  22984
# vocabulary index is:  22984
# vocabulary index is:  22984

# %%
count_vectorizer.get_feature_names_out()[23033]
# Out:
# 'safety issues'

# %%
bigram_freq.iloc[23033]
# Out:
# term    safety issues
# freq                5
# Name: safety issues, dtype: object

# %%
corpus.apply(lambda x : "rural areas" in x).sum()
# Out:
# 375

# %%
corpus.apply(lambda x : x.count("rural areas")).sum()
# Out:
# 438

# %%
corpus.apply(lambda x : x.lower().count("rural areas")).sum()
# Out:
# 442

# %% [markdown]
# ### computing word frequency
#
# get count vector and then followed by sum is an expensive way to get word frequency
#  - may be better rely on vocabulary, which is a dictionary

# %%
bigram_freq.sort_values(by="freq", ascending =False)[:30]
# Out:
#                                             term  freq
# human rights                        human rights  2002
# climate change                    climate change  1360
# et al                                      et al  1253
# oecd countries                    oecd countries   949
# developing countries        developing countries   895
# health care                          health care   888
# united states                      united states   833
# long term                              long term   798
# international law              international law   779
# labour market                      labour market   760
# gender equality                  gender equality   627
# energy efficiency              energy efficiency   548
# private sector                    private sector   535
# renewable energy                renewable energy   513
# united nations                    united nations   497
# climate finance                  climate finance   489
# sustainable development  sustainable development   484
# economic growth                  economic growth   469
# rural areas                          rural areas   441
# mental health                      mental health   423
# decision making                  decision making   419
# world bank                            world bank   418
# rule law                                rule law   400
# higher education                higher education   392
# land use                                land use   390
# labour force                        labour force   364
# primary care                        primary care   361
# united kingdom                    united kingdom   354
# socio economic                    socio economic   350
# oecd average                        oecd average   334

# %%
count_vectorizer.vocabulary_
# Out:
# {'gender perspective': 10495,
#  'labour markets': 14457,
#  'gender segregated': 10504,
#  'new business': 17396,
#  'business opportunities': 3262,
#  'peripheral areas': 18829,
#  'boys girls': 3088,
#  'women men': 27956,
#  'men work': 16433,
#  'young people': 28367,
#  'people working': 18731,
#  'young adults': 28360,
#  'described earlier': 6436,
#  'spend time': 24682,
#  'average figure': 2503,
#  'large differences': 14608,
#  'parts population': 18542,
#  'likely limited': 15266,
#  'limited access': 15297,
#  'access primary': 912,
#  'primary care': 20029,
#  'care addition': 3437,
#  'addition poor': 1220,
#  'findings consistent': 9787,
#  'previous work': 19972,
#  'differences wage': 6823,
#  'wage inequality': 27475,
#  'inequality countries': 13354,
#  'fournier koske': 10181,
#  'koske 2012': 14433,
#  'returns education': 22589,
#  'education important': 7714,
#  'important role': 12474,
#  'earnings inequality': 7407,
#  '2014 countries': 471,
#  'supply demand': 25376,
#  'demand skills': 6324,
#  'role played': 22933,
#  'labour market': 14456,
#  'market institutions': 16115,
#  'minimum wages': 16593,
#  'rules governing': 22969,
#  'wage bargaining': 27464,
#  'quantity quality': 21162,
#  'quality water': 21151,
#  'mediterranean sea': 16361,
#  'water quality': 27631,
#  'local authorities': 15434,
#  'drinking water': 7330,
#  'ministry health': 16623,
#  'health ministry': 11513,
#  'use agricultural': 26975,
#  'agricultural sector': 1597,
#  'previous chapters': 19960,
#  'food systems': 10023,
#  'food security': 10017,
#  'better nutrition': 2913,
#  'nutritional outcomes': 17774,
#  'war terror': 27504,
#  'framework international': 10212,
#  'international law': 13928,
#  'cambridge university': 3298,
#  'university press': 26851,
#  'challenges international': 3812,
#  'international legal': 13930,
#  'legal order': 14982,
#  'legal principles': 14987,
#  'state responsibility': 24843,
#  'relatively new': 21956,
#  'threats terrorism': 26210,
#  'inside outside': 13662,
#  'various legal': 27312,
#  'legal issues': 14976,
#  'application international': 1894,
#  'international human': 13918,
#  'human rights': 12112,
#  'rights international': 22742,
#  'international humanitarian': 13919,
#  'humanitarian law': 12124,
#  'law international': 14764,
#  'international criminal': 13900,
#  'criminal law': 5858,
#  'higher labour': 11806,
#  'labour force': 14448,
#  'force participation': 10030,
#  'drug use': 7359,
#  'chronic conditions': 4185,
#  'prime age': 20057,
#  'contrast share': 5034,
#  'share working': 23913,
#  'working age': 28185,
#  'age households': 1482,
#  'households working': 12062,
#  'remained relatively': 22040,
#  'relatively stable': 21964,
#  'time countries': 26228,
#  '15 percentage': 137,
#  'percentage points': 18749,
#  'men employment': 16416,
#  'employment participation': 8269,
#  'households male': 12049,
#  'working time': 28204,
#  'time year': 26296,
#  'year compared': 28281,
#  'women working': 28041,
#  'hours week': 11979,
#  'total costs': 26353,
#  'public private': 20992,
#  'upper secondary': 26880,
#  'secondary education': 23328,
#  'vary considerably': 27333,
#  'state subsidies': 24848,
#  'regional disparities': 21733,
#  'abstract paper': 814,
#  'paper demonstrates': 18322,
#  'real life': 21375,
#  'novel approach': 17669,
#  'approach social': 1938,
#  'social science': 24363,
#  'artificial intelligence': 2221,
#  'conflict peace': 4811,
#  'model based': 16703,
#  'critical issues': 5890,
#  'issues related': 14181,
#  'year 2020': 28274,
#  'international relations': 13966,
#  'model used': 16709,
#  'average annual': 2484,
#  'annual income': 1863,
#  'rural areas': 22984,
#  'areas new': 2099,
#  'centres hospitals': 3757,
#  'urban areas': 26886,
#  'areas similar': 2118,
#  'did exist': 6792,
#  'insurance based': 13759,
#  'based schemes': 2720,
#  'create new': 5811,
#  'new urban': 17521,
#  'community health': 4584,
#  'health centres': 11459,
#  'production process': 20261,
#  'majority poor': 15838,
#  'poor people': 19460,
#  'dependent agriculture': 6388,
#  'water supplies': 27666,
#  'biodiversity environmental': 2987,
#  'environmental services': 8694,
#  'climate change': 4302,
#  'carbon price': 3419,
#  'usd 30': 26961,
#  '30 tonne': 597,
#  'nuclear energy': 17680,
#  'average cost': 2492,
#  'fuel price': 10282,
#  'price changes': 19978,
#  'changes low': 3936,
#  'low proportion': 15622,
#  'fuel costs': 10275,
#  'lifetime costs': 15232,
#  'costs nuclear': 5243,
#  'nuclear power': 17685,
#  'power generation': 19803,
#  'costs include': 5230,
#  'basic education': 2748,
#  'education years': 7828,
#  'years primary': 28343,
#  'primary school': 20049,
#  'school years': 23197,
#  'secondary school': 23337,
#  'school students': 23188,
#  'senior secondary': 23624,
#  'vocational school': 27422,
#  'general education': 10527,
#  'vocational education': 27419,
#  'secondary schools': 23339,
#  'education chapter': 7662,
#  'chapter considers': 3972,
#  'higher education': 11786,
#  'law standard': 14830,
#  'criminal liability': 5859,
#  'international crime': 13898,
#  'political freedom': 19365,
#  '2010 number': 382,
#  'line oecd': 15346,
#  'oecd average': 17864,
#  'example rural': 9108,
#  'rural dwellers': 22989,
#  'additional information': 1237,
#  'disparities access': 7130,
#  'access rural': 920,
#  'rural populations': 23006,
#  'access care': 851,
#  'care patient': 3505,
#  'understanding nature': 26753,
#  'barriers access': 2611,
#  'available data': 2434,
#  'socio economic': 24412,
#  'economic characteristics': 7476,
#  'play role': 19020,
#  'regions provide': 21792,
#  'provide services': 20770,
#  'paper examines': 18326,
#  'early forced': 7387,
#  'specific focus': 24626,
#  'east africa': 7415,
#  'address issue': 1262,
#  'using international': 27212,
#  'international regional': 13964,
#  'regional national': 21757,
#  'national legal': 16990,
#  'legal norms': 14979,
#  'currently place': 6007,
#  'east african': 7416,
#  'african countries': 1446,
#  'countries examined': 5403,
#  'rwanda uganda': 23019,
#  'section gives': 23359,
#  'global level': 10752,
#  'respond new': 22465,
#  'new challenges': 17402,
#  'strong links': 25083,
#  'remote areas': 22069,
#  'analyses impact': 1788,
#  'sector universities': 23462,
#  'short cycle': 23945,
#  'sub sectors': 25277,
#  'tertiary education': 26169,
#  'education training': 7819,
#  'participation collaboration': 18398,
#  'different types': 6926,
#  'analysis impact': 1808,
#  'impact policy': 12280,
#  'policy changes': 19192,
#  'negative effect': 17332,
#  'policy implemented': 19242,
#  'article discusses': 2190,
#  'corruption government': 5159,
#  'government officials': 10962,
#  'legal research': 15002,
#  'research approach': 22251,
#  'empirical data': 8206,
#  'data collected': 6067,
#  'main findings': 15749,
#  'state budget': 24790,
#  'major source': 15830,
#  'abuse power': 823,
#  'rules regulations': 22975,
#  'law enforcement': 14739,
#  'organizational structure': 18145,
#  'legal culture': 14963,
#  'highly unequal': 11908,
#  'unequal countries': 26785,
#  'countries like': 5499,
#  'south africa': 24508,
#  'shown figure': 23959,
#  'figure 12': 9614,
#  'similar findings': 24075,
#  'findings oecd': 9789,
#  'oecd countries': 17868,
#  'countries oecd': 5529,
#  'oecd forthcoming': 17884,
#  'late 1980s': 14681,
#  'government policy': 10970,
#  'tax transfer': 25825,
#  'transfer schemes': 26538,
#  'public service': 21007,
#  'service provision': 23664,
#  'important social': 12477,
#  'social contract': 24270,
#  'women work': 28039,
#  'economic disadvantage': 7498,
#  'equal pay': 8721,
#  'work equal': 28080,
#  'equal value': 8731,
#  'right equality': 22646,
#  'cedaw committee': 3643,
#  'total revenue': 26393,
#  'national government': 16964,
#  'local governments': 15463,
#  'does account': 7207,
#  'social economic': 24284,
#  'economic environmental': 7507,
#  'environmental damage': 8646,
#  'small island': 24199,
#  'island states': 14138,
#  '70 cent': 716,
#  'cent total': 3713,
#  'basic service': 2767,
#  'service infrastructure': 23659,
#  'long standing': 15536,
#  'short term': 23952,
#  'recent studies': 21442,
#  'political corruption': 19349,
#  'using data': 27203,
#  'highly educated': 11894,
#  'political party': 19385,
#  'significantly increases': 24059,
#  'political parties': 19384,
#  'democratic accountability': 6334,
#  'educational outcomes': 7847,
#  'programmes targeted': 20432,
#  'chapter places': 3998,
#  'particular emphasis': 18446,
#  'areas priority': 2111,
#  'effective ways': 7929,
#  'ways use': 27710,
#  'disadvantaged students': 7066,
#  'monitoring learning': 16756,
#  'learning outcomes': 14916,
#  'student groups': 25131,
#  'indigenous cultures': 13223,
#  'chilean education': 4167,
#  'chapter reviews': 4003,
#  'education provision': 7780,
#  'special needs': 24570,
#  'needs education': 17289,
#  'groups students': 11246,
#  'targeted specific': 25763,
#  'specific groups': 24628,
#  'strengths challenges': 25056,
#  'finally chapter': 9661,
#  'chapter provides': 4001,
#  'specific policy': 24646,
#  'policy recommendations': 19305,
#  'discussed context': 7100,
#  'oecd 2009a': 17829,
#  'oecd 2012b': 17841,
#  'risk management': 22850,
#  'change oecd': 3881,
#  'country level': 5708,
#  '2011 oecd': 411,
#  'oecd 2013b': 17845,
#  'policy conclusions': 19199,
#  'specific types': 24669,
#  'especially context': 8803,
#  'use management': 27041,
#  'management practices': 15996,
#  'article seeks': 2213,
#  'law protection': 14800,
#  'protection human': 20658,
#  'rights law': 22747,
#  'law european': 14744,
#  'european convention': 8975,
#  'convention human': 5104,
#  'article suggests': 2216,
#  'legal theory': 15016,
#  'european court': 8977,
#  'court human': 5756,
#  'case law': 3589,
#  'rights states': 22793,
#  'modern state': 16722,
#  'private spheres': 20150,
#  'discrimination women': 7090,
#  'women lack': 27939,
#  'economic decision': 7492,
#  'decision making': 6211,
#  'violence women': 27406,
#  'economic social': 7579,
#  'social cultural': 24276,
#  'power relations': 19823,
#  'relations men': 21913,
#  'men women': 16432,
#  'resources private': 22427,
#  'private public': 20137,
#  'directly related': 7041,
#  'unequal distribution': 26786,
#  'distribution labour': 7169,
#  'unpaid domestic': 26861,
#  'domestic work': 7303,
#  'building climate': 3191,
#  'change resilience': 3890,
#  'resilience reducing': 22330,
#  'reducing inequalities': 21589,
#  'dimensions development': 6995,
#  'frequency intensity': 10261,
#  'climate hazards': 4318,
#  'end poverty': 8346,
#  'poverty hunger': 19733,
#  'promote sustainable': 20565,
#  'sustainable agriculture': 25562,
#  'informal sector': 13427,
#  'external shocks': 9331,
#  'effective social': 7918,
#  'social protection': 24352,
#  'protection coverage': 20651,
#  'low paid': 15610,
#  'access networks': 905,
#  'capacity building': 3322,
#  'levels government': 15172,
#  'investment physical': 14068,
#  'water sanitation': 27646,
#  'hard infrastructure': 11418,
#  'infrastructure provision': 13568,
#  'soft infrastructure': 24423,
#  'development skills': 6750,
#  'technical expertise': 25940,
#  'effective governance': 7892,
#  'governance water': 10882,
#  'water policy': 27619,
#  'federal level': 9538,
#  'level national': 15101,
#  'national water': 17060,
#  'water commission': 27568,
#  'body charge': 3052,
#  'charge water': 4017,
#  'water planning': 27617,
#  'provision water': 20899,
#  'water services': 27654,
#  'varying levels': 27343,
#  'capacity resources': 3348,
#  'water law': 27606,
#  'water resource': 27638,
#  'river basin': 22876,
#  'basin organisations': 2777,
#  'implementing agencies': 12378,
#  'progress achieved': 20442,
#  'water resources': 27639,
#  'resources management': 22414,
#  'regulatory framework': 21823,
#  'developed based': 6520,
#  'blockchain technology': 3041,
#  'city centres': 4224,
#  'design appropriate': 6441,
#  'real time': 21377,
#  'blockchain layer': 3039,
#  'june 2015': 14292,
#  'public health': 20957,
#  'health safety': 11548,
#  'new measures': 17465,
#  'inequality terms': 13390,
#  'poverty levels': 19746,
#  'mean income': 16223,
#  'income levels': 12845,
#  'possible explanation': 19602,
#  'increases income': 13074,
#  'segment population': 23571,
#  'population region': 19544,
#  'analysis presented': 1820,
#  'following sections': 9969,
#  'eu charter': 8930,
#  'charter fundamental': 4020,
#  'fundamental rights': 10317,
#  'entry force': 8600,
#  'treaty lisbon': 26657,
#  'court justice': 5762,
#  'active role': 1103,
#  'role developing': 22902,
#  'eu legal': 8942,
#  'issues need': 14175,
#  'need addressed': 17187,
#  'great importance': 11065,
#  'conservation biodiversity': 4840,
#  '17 cent': 159,
#  'using traditional': 27227,
#  'used food': 27139,
#  'food quality': 10012,
#  'rising sea': 22825,
#  'sea levels': 23289,
#  'extreme weather': 9342,
#  'weather events': 27719,
#  'natural habitats': 17102,
#  'coral reefs': 5133,
#  'changes affect': 3910,
#  'affect people': 1407,
#  'poorest vulnerable': 19487,
#  'concerted action': 4756,
#  'urgently needed': 26944,
#  'strengthen resilience': 25045,
#  'climate related': 4333,
#  'related hazards': 21864,
#  'past decade': 18555,
#  'cultural heritage': 5947,
#  'attention international': 2357,
#  'international national': 13940,
#  'national policy': 17010,
#  'policy agendas': 19176,
#  'traditional medicine': 26476,
#  'explore relationship': 9279,
#  'practical implications': 19841,
#  'rights public': 22775,
#  'health development': 11471,
#  'fundamental principles': 10314,
#  'electricity firms': 8089,
#  'investment funds': 14051,
#  'business model': 3258,
#  'based specific': 2729,
#  'specific characteristics': 24614,
#  'age sex': 1492,
#  'economic position': 7551,
#  'married women': 16170,
#  'working arrangements': 28186,
#  'reconciling work': 21472,
#  'work family': 28084,
#  'family life': 9440,
#  'parental leave': 18364,
#  'facilitate transition': 9369,
#  'appraisal process': 1903,
#  'process requires': 20192,
#  'school leaders': 23161,
#  'review literature': 22611,
#  'school leader': 23160,
#  'leader appraisal': 14873,
#  'et al': 8907,
#  'meetings school': 16389,
#  'increase effectiveness': 12933,
#  'leader performance': 14874,
#  'efforts required': 8053,
#  'longer term': 15547,
#  'costs need': 5241,
#  'need considered': 17198,
#  'teachers schools': 25894,
#  'qualified teachers': 21064,
#  'role teachers': 22950,
#  'teaching learning': 25910,
#  'learning international': 14908,
#  'international survey': 13978,
#  'teachers school': 25893,
#  'understanding issues': 26750,
#  'indigenous students': 13234,
#  'relevant professional': 21998,
#  'professional development': 20316,
#  'holistic approach': 11932,
#  'indigenous peoples': 13231,
#  'contribute overall': 5045,
#  'provinces territories': 20879,
#  'indigenous non': 13228,
#  'non indigenous': 17577,
#  'people better': 18669,
#  'better understood': 2935,
#  'factors make': 9399,
#  'experiencing deprivation': 9261,
#  'vice versa': 27365,
#  'densely populated': 6372,
#  'little impact': 15371,
#  'impact children': 12238,
#  'france uk': 10236,
#  'female genital': 9566,
#  'genital mutilation': 10611,
#  'child marriage': 4048,
#  'reproductive health': 22167,
#  'health issues': 11504,
#  'issues including': 14168,
#  'infant mortality': 13396,
#  'sex selective': 23842,
#  'forms discrimination': 10157,
#  'status women': 24932,
#  'women society': 28016,
#  '60 years': 698,
#  'provisions international': 20901,
#  'legal policy': 14984,
#  'policy frameworks': 19233,
#  'measures address': 16264,
#  'harmful practices': 11423,
#  'mammal species': 15917,
#  'regional scale': 21770,
#  'people poverty': 18710,
#  'poverty exclusion': 19720,
#  'millions people': 16574,
#  'inclusive innovation': 12780,
#  'economic development': 7495,
#  'development especially': 6622,
#  'emerging developing': 8155,
#  'developing economies': 6541,
#  'estimated billion': 8883,
#  'billion people': 2969,
#  'world population': 28233,
#  'population lived': 19534,
#  'world bank': 28211,
#  'multi stakeholder': 16812,
#  'member states': 16395,
#  'major groups': 15814,
#  'collaborative partnership': 4420,
#  'partnership forests': 18536,
#  'non governmental': 17571,
#  'governmental organizations': 11017,
#  'major group': 15813,
#  'scientific technological': 23260,
#  'farmers small': 9491,
#  'small forest': 24195,
#  'children youth': 4155,
#  'african states': 1456,
#  'states united': 24904,
#  'united states': 26826,
#  'states america': 24862,
#  'republic korea': 22184,
#  'norway finland': 17653,
#  'capital gains': 3376,
#  'national assessment': 16901,
#  'danish government': 6044,
#  'result differences': 22519,
#  'comparison oecd': 4659,
#  'remains unclear': 22066,
#  'gini coefficient': 10650,
#  'oecd standards': 17911,
#  'lower higher': 15661,
#  'tends increase': 26063,
#  'increase inequality': 12950,
#  'current transfers': 5999,
#  'transfers paid': 26545,
#  'tax reform': 25816,
#  'relevant agencies': 21973,
#  'agencies involved': 1520,
#  'mental health': 16440,
#  'health services': 11552,
#  'children needs': 4122,
#  'training teachers': 26524,
#  'teachers programme': 25887,
#  'social emotional': 24286,
#  'learning programmes': 14918,
#  'learning social': 14923,
#  'social aspects': 24250,
#  'wide range': 27767,
#  'range public': 21233,
#  'essential public': 8844,
#  'sub national': 25268,
#  'national level': 16992,
#  'health workforce': 11571,
#  'good example': 10823,
#  'number national': 17726,
#  'trade industry': 26436,
#  'manufacturing sectors': 16040,
#  'available national': 2448,
#  'national accounts': 16894,
#  'energy related': 8433,
#  'electricity gas': 8090,
#  'water supply': 27667,
#  'households women': 12061,
#  'collection gender': 4434,
#  'gender distribution': 10463,
#  'distribution time': 7181,
#  'differ significantly': 6806,
#  'time allocation': 26215,
#  'women spend': 28019,
#  'time men': 26260,
#  'greater share': 11118,
#  'share time': 23906,
#  'energy technologies': 8456,
#  'grid extension': 11174,
#  'mini grid': 16578,
#  'greenhouse gas': 11166,
#  'structural economic': 25113,
#  'emission intensity': 8164,
#  'intensity production': 13817,
#  'efficiency improvements': 7983,
#  'changes energy': 3922,
#  'energy mix': 8410,
#  'energy intensive': 8402,
#  'international agreements': 13861,
#  'path sustainable': 18568,
#  'sustainable development': 25567,
#  'challenge facing': 3793,
#  'high priority': 11737,
#  'set forth': 23789,
#  'public enterprises': 20942,
#  'public institutions': 20963,
#  'institutions private': 13737,
#  'private sector': 20142,
#  'sector public': 23448,
#  'day day': 6174,
#  'overall goal': 18215,
#  'goal increase': 10800,
#  'forestry sector': 10115,
#  'sector national': 23431,
#  'national economy': 16942,
#  'rural development': 22988,
#  'development sustainable': 6762,
#  'sustainable forest': 25574,
#  'forest management': 10086,
#  'renewable resources': 22085,
#  'resources protection': 22430,
#  'protection local': 20663,
#  'local global': 15460,
#  'global environment': 10726,
#  'products services': 20311,
#  'improving quality': 12599,
#  'quality life': 21117,
#  'based quality': 2715,
#  'lowest cost': 15696,
#  'long way': 15540,
#  'offers new': 17930,
#  'new ways': 17526,
#  'supply chain': 25370,
#  'goods services': 10844,
#  'critically endangered': 5901,
#  'population size': 19550,
#  'species wild': 24602,
#  'protected areas': 20636,
#  'shared mobility': 23917,
#  'power plant': 19816,
#  'renewable power': 22083,
#  'power plants': 19817,
#  'grid operators': 11179,
#  'transport infrastructure': 26606,
#  'business models': 3259,
#  'power grids': 19807,
#  'increased awareness': 13019,
#  'males females': 15916,
#  'region south': 21710,
#  'south east': 24518,
#  'east asia': 7417,
#  'provision public': 20896,
#  'public power': 20990,
#  'public spaces': 21012,
#  'people world': 18732,
#  'safe water': 23029,
#  'sanitation facilities': 23063,
#  'health organization': 11518,
#  'different ways': 6933,
#  'ways different': 27704,
#  'different places': 6891,
#  'sanitation hygiene': 23065,
#  'public policy': 20988,
#  'hydrological cycle': 12141,
#  'physical infrastructure': 18886,
#  'developing countries': 6538,
#  'productive capacity': 20279,
#  'economic infrastructure': 7525,
#  'shown table': 23960,
#  'crs database': 5927,
#  '38 cent': 623,
#  'income group': 12831,
#  'free trade': 10246,
#  'combined effects': 4470,
#  'effects policies': 7964,
#  'transaction costs': 26528,
#  'price transmission': 20005,
#  'global information': 10747,
#  'early warning': 7398,
#  'recent food': 21424,
#  'food price': 10004,
#  'price increases': 19986,
#  'machinery equipment': 15717,
#  'mid 2000s': 16505,
#  'agro food': 1625,
#  'poverty extreme': 19721,
#  'extreme poverty': 9341,
#  'poverty fell': 19724,
#  'poverty rate': 19771,
#  'period 2015': 18814,
#  '2015 2016': 486,
#  'likely remain': 15279,
#  'use national': 27046,
#  'national context': 16929,
#  'comparability countries': 4607,
#  'development strategy': 6757,
#  'infrastructure planning': 13563,
#  'range new': 21229,
#  'consumer goods': 4934,
#  'economies scale': 7612,
#  'scale production': 23098,
#  'intermediate goods': 13849,
#  'export markets': 9291,
#  'india example': 13168,
#  'infrastructure required': 13570,
#  'manufacturing sector': 16039,
#  'private investment': 20122,
#  'risk factors': 22841,
#  'factors associated': 9385,
#  'associated economic': 2315,
#  'implementation programmes': 12361,
#  'introduce new': 14019,
#  'new approaches': 17392,
#  'public bodies': 20923,
#  'joint efforts': 14253,
#  'different levels': 6875,
#  'improve population': 12524,
#  'education health': 7705,
#  'good quality': 10836,
#  'conditional transfer': 4776,
#  'transfer programmes': 26537,
#  'considerable efforts': 4856,
#  'efforts create': 8035,
#  'exclusion inclusion': 9144,
#  'reaching poor': 21361,
#  'fiszbein schady': 9884,
#  'schady 2009': 23112,
#  'able identify': 793,
#  'help reduce': 11645,
#  'medical association': 16332,
#  'sharing information': 23929,
#  '2004 2009': 271,
#  'collected information': 4426,
#  'health care': 11457,
#  'care limited': 3489,
#  'income urban': 12891,
#  'urban residents': 26927,
#  'rural residents': 23010,
#  'remains large': 22056,
#  'rural poverty': 23007,
#  'poverty rates': 19772,
#  'viet nam': 27376,
#  'increasing agricultural': 13087,
#  'agricultural productivity': 1592,
#  'rural incomes': 22997,
#  'total population': 26384,
#  '1990 92': 200,
#  '2012 14': 419,
#  'benefits reduced': 2866,
#  'infrastructure costs': 13535,
#  'car use': 3398,
#  'people live': 18697,
#  'higher cost': 11778,
#  'saint nazaire': 23050,
#  'average women': 2547,
#  'greatest share': 11130,
#  'korea japan': 14421,
#  'japan mexico': 14213,
#  'mexico portugal': 16488,
#  'unpaid work': 26865,
#  'work women': 28146,
#  'time day': 26230,
#  'absolute values': 811,
#  'hours day': 11975,
#  'average compared': 2490,
#  'hours men': 11976,
#  'men oecd': 16428,
#  'oecd gender': 17885,
#  'gender data': 10454,
#  'oecd 2014a': 17848,
#  'inadequate access': 12605,
#  'infrastructure water': 13582,
#  'washing machines': 27508,
#  'increases total': 13084,
#  'time required': 26275,
#  'unable access': 26724,
#  'access government': 879,
#  'government support': 11004,
#  'support programmes': 25476,
#  'programmes lack': 20403,
#  'investment costs': 14041,
#  'metres sea': 16465,
#  'sea level': 23288,
#  'negotiation process': 17349,
#  'new water': 17524,
#  'water allocation': 27553,
#  'education institutions': 7730,
#  'mechanisms support': 16320,
#  'investment infrastructure': 14057,
#  'rates return': 21329,
#  'countries example': 5404,
#  'example united': 9116,
#  'united kingdom': 26823,
#  'funding scheme': 10334,
#  'august 2008': 2379,
#  'year period': 28292,
#  'funding available': 10325,
#  'commercial banks': 4485,
#  'relatively short': 21960,
#  'years compared': 28321,
#  'approach taken': 1939,
#  '12 months': 88,
#  'patent office': 18566,
#  'provided private': 20795,
#  'aarhus convention': 765,
#  'access justice': 893,
#  'scope application': 23262,
#  'projects implemented': 20522,
#  'national legislation': 16991,
#  'obligations convention': 17796,
#  'range possible': 21232,
#  'judicial review': 14276,
#  'justice environmental': 14314,
#  'provisions convention': 20900,
#  'right property': 22658,
#  'law time': 14838,
#  'non eu': 17561,
#  'eu member': 8945,
#  'member state': 16394,
#  'state party': 24833,
#  'relations ir': 21912,
#  'political violence': 19407,
#  'rights freedom': 22720,
#  'particularly case': 18473,
#  'article argues': 2170,
#  'makes possible': 15880,
#  'law crime': 14727,
#  'social transformation': 24383,
#  'attorney general': 2369,
#  'equality law': 8746,
#  'right freedom': 22649,
#  'freedom expression': 10250,
#  'close relationship': 4361,
#  'human right': 12111,
#  'review article': 22603,
#  'significant economic': 23998,
#  'benefits water': 2874,
#  'billion annually': 2966,
#  'environmental protection': 8686,
#  'protection agency': 20647,
#  'pollution levels': 19422,
#  'recreational activities': 21480,
#  'algal blooms': 1717,
#  'levels water': 15200,
#  'growth effect': 11295,
#  'honduras mexico': 11950,
#  '2002 2008': 258,
#  '1990 2008': 194,
#  'distribution effect': 7166,
#  'effect reducing': 7877,
#  'reducing poverty': 21597,
#  'poverty figure': 19725,
#  'figure 10': 9612,
#  'approximately 40': 1968,
#  '40 years': 639,
#  'increasing role': 13127,
#  'role play': 22932,
#  'play supporting': 19022,
#  'formative assessment': 10153,
#  'assessment assessment': 2273,
#  'assessment learning': 2278,
#  'chapter presents': 3999,
#  'brief overview': 3109,
#  'recent years': 21449,
#  'years particular': 28341,
#  'classroom practice': 4267,
#  'presents evidence': 19920,
#  'evidence impact': 9021,
#  'public administration': 20915,
#  'critical social': 5895,
#  'article identifies': 2202,
#  'historical evolution': 11915,
#  'critical theory': 5898,
#  'development critical': 6604,
#  'form social': 10135,
#  'limited use': 15331,
#  'use modern': 27045,
#  'modern contraceptive': 16714,
#  'contraceptive methods': 5023,
#  '16 cent': 147,
#  'cent respectively': 3710,
#  'blood pressure': 3043,
#  'figure shows': 9646,
#  'shows percentage': 23968,
#  'pregnant women': 19887,
#  'women receive': 27993,
#  'prenatal care': 19892,
#  '60 cent': 693,
#  '100 cent': 54,
#  'flora fauna': 9912,
#  'tree species': 26662,
#  'red data': 21494,
#  'data book': 6064,
#  'plant species': 19002,
#  'species including': 24594,
#  'trees bushes': 26663,
#  'chapter 10': 3959,
#  'requires government': 22234,
#  'policy tools': 19330,
#  'chapter explores': 3984,
#  'explores role': 9284,
#  'role government': 22914,
#  'transition sustainable': 26566,
#  'sustainable lifestyles': 25585,
#  'policy options': 19278,
#  'promoting sustainable': 20577,
#  'industrialised countries': 13333,
#  'population growth': 19523,
#  'high levels': 11717,
#  'levels consumption': 15157,
#  'emerging economies': 8156,
#  'discriminatory practices': 7095,
#  'financial institutions': 9732,
#  'formal financial': 10142,
#  'institutions need': 13731,
#  'entry barriers': 8599,
#  'improve performance': 12523,
#  'growth female': 11302,
#  'female owned': 9574,
#  'owned businesses': 18256,
#  'countries experience': 5409,
#  'floods droughts': 9910,
#  'developed countries': 6522,
#  'severe drought': 23830,
#  'large scale': 14645,
#  'near universal': 17138,
#  'environmental justice': 8669,
#  'justice women': 14325,
#  'large proportion': 14639,
#  'political ecology': 19358,
#  'open access': 17988,
#  'social class': 24264,
#  'targeting women': 25767,
#  'indigenous people': 13230,
#  'general population': 10540,
#  'aim achieve': 1635,
#  'mortality rate': 16782,
#  'deaths 000': 6183,
#  '2015 countries': 495,
#  'countries aim': 5299,
#  '35 000': 614,
#  '000 live': 9,
#  'live births': 15379,
#  '45 000': 646,
#  'countries achieve': 5287,
#  'korean government': 14431,
#  'supply sanitation': 25386,
#  'sanitation infrastructure': 23066,
#  'local level': 15476,
#  'water tariffs': 27669,
#  ...}

# %%
bigram_freq.query("freq==5").nunique()
# Out:
# term    6595
# freq       1
# dtype: int64

# %% [markdown]
# ### putting together as a function
#  - enable stop words removal
#  - enable unigram, bigram, tri-gram

# %%
def get_term_freq(corpus, ngram_range = (1, 1), stop_words = None, min_df = 5): # min_df has to be 2 or larger
    count_vectorizer = CountVectorizer(ngram_range = ngram_range, stop_words = stop_words, min_df =min_df)
    count_vector = count_vectorizer.fit_transform(corpus).toarray()
    count_vector_df = pd.DataFrame(count_vector, columns=count_vectorizer.get_feature_names_out())
    term_freq = pd.DataFrame({"term": count_vector_df.columns.values, "freq" : count_vector_df.sum(axis=0)})
    return term_freq

# %%
corpus = text_df.text
term_freq_1_1_remove_stop = get_term_freq(corpus, stop_words='english').sort_values(by="freq", ascending=False)
term_freq_1_1_keep_stop = get_term_freq(corpus).sort_values(by="freq", ascending=False)
term_freq_2_2_remove_stop = get_term_freq(corpus, ngram_range = (2,2), stop_words = 'english').sort_values(by="freq", ascending=False)
term_freq_2_2_keep_stop = get_term_freq(corpus, ngram_range = (2,2)).sort_values(by="freq", ascending=False)

# %%
term_freq_2_2_keep_stop.head(50)
# Out:
#                           term   freq
# of the                  of the  19574
# in the                  in the  16048
# to the                  to the   7295
# and the                and the   7048
# on the                  on the   5475
# for the                for the   4176
# to be                    to be   3762
# such as                such as   3409
# by the                  by the   3404
# with the              with the   3040
# at the                  at the   2965
# it is                    it is   2883
# that the              that the   2485
# per cent              per cent   2298
# can be                  can be   2221
# from the              from the   2164
# number of            number of   2111
# as well                as well   2109
# as the                  as the   2109
# for example        for example   2082
# human rights      human rights   2002
# has been              has been   1985
# well as                well as   1951
# access to            access to   1858
# there is              there is   1714
# have been            have been   1698
# based on              based on   1614
# in this                in this   1533
# is the                  is the   1498
# the united          the united   1454
# use of                  use of   1435
# this is                this is   1398
# the same              the same   1363
# climate change  climate change   1360
# should be            should be   1317
# need to                need to   1309
# et al                    et al   1253
# of these              of these   1221
# the national      the national   1205
# there are            there are   1203
# due to                  due to   1192
# and other            and other   1187
# is not                  is not   1182
# the most              the most   1149
# more than            more than   1132
# the oecd              the oecd   1127
# may be                  may be   1120
# and to                  and to   1117
# will be                will be   1104
# part of                part of   1078

# %%
term_freq_2_2_remove_stop.head(50)
# Out:
#                                             term  freq
# human rights                        human rights  2002
# climate change                    climate change  1360
# et al                                      et al  1253
# oecd countries                    oecd countries   949
# developing countries        developing countries   895
# health care                          health care   888
# united states                      united states   833
# long term                              long term   798
# international law              international law   779
# labour market                      labour market   760
# gender equality                  gender equality   627
# energy efficiency              energy efficiency   548
# private sector                    private sector   535
# renewable energy                renewable energy   513
# united nations                    united nations   497
# climate finance                  climate finance   489
# sustainable development  sustainable development   484
# economic growth                  economic growth   469
# rural areas                          rural areas   441
# mental health                      mental health   423
# decision making                  decision making   419
# world bank                            world bank   418
# rule law                                rule law   400
# higher education                higher education   392
# land use                                land use   390
# labour force                        labour force   364
# primary care                        primary care   361
# united kingdom                    united kingdom   354
# socio economic                    socio economic   350
# oecd average                        oecd average   334
# low income                            low income   333
# public health                      public health   329
# men women                              men women   329
# social protection              social protection   328
# supreme court                      supreme court   313
# women men                              women men   312
# developed countries          developed countries   312
# percentage points              percentage points   309
# protected areas                  protected areas   304
# public private                    public private   299
# urban areas                          urban areas   294
# economic social                  economic social   287
# european union                    european union   287
# recent years                        recent years   285
# civil society                      civil society   281
# food security                      food security   281
# water resources                  water resources   279
# secondary education          secondary education   276
# criminal law                        criminal law   275
# national level                    national level   274

# %%
term_freq_2_2_keep_stop.shape, term_freq_2_2_remove_stop.shape
# Out:
# ((66411, 2), (28393, 2))
