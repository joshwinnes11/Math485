# %% [markdown]
# # Data Investigation
#
# Often times when we explore data for the first time, we have to spend time looking at what is missing in the data, or what needs to be changed. Data files rarely if ever are perfect for use immediately once you get them. Additionally, it is often unwise to utilize data for predictive modeling or statistical analysis without knowing some of the context for the data and looking at its contents.
#
# Python has a helpful package called `pandas` which is purpose-built for looking at and manipulating data, and a lot of what we will work on in this section will involve using it.

# %% [markdown]
# ## Setup
# The first thing we typically do when dealing with data in Python is to import the `pandas` package and one of its dependencies, `numpy`.

# %%
import pandas as pd
import numpy as np

# %%
import os
os.chdir('/Users/joshwinnes/Library/Mobile Documents/com~apple~CloudDocs/Wheaton College/fall 2024/topics in data science/data') # change to your directory
df = pd.read_csv('dhs_service_records_synthesized_final.csv')

# %% [markdown]
# ## Simple Data Inspection
#
# Before doing anything with the data, it is good practice to take a look at a few samples from the dataset. Here, we're going to take a look at the first ten rows and the last seven rows, or the head and tail of the data; this is a function that is easy to call, and it is good practice to call either of these often so that you know how a dataset evolves over time.

# %%
df.head()
# Out:
#    synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT  \
# 0  SYNTHETIC DATA         1626      2021    01/31/2021
# 1  SYNTHETIC DATA         1626      2021    02/28/2021
# 2  SYNTHETIC DATA         1626      2021    03/31/2021
# 3  SYNTHETIC DATA         1626      2021    04/30/2021
# 4  SYNTHETIC DATA         1626      2021    05/31/2021
#
#                                              service  GEO_AREA  age  DOB  DOD  \
# 0  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
# 1  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
# 2  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
# 3  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
# 4  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
#
#    GENDER  GENDER_IDENTITY  SEX_ORIENT  LEGAL_SEX     RACE   ETHNICITY  \
# 0  1~Male              NaN         NaN        NaN  1~White  99~Unknown
# ...

# %%
df.tail(3)
# Out:
#          synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT   service  \
# 7116131  SYNTHETIC DATA       533991      2021    11/30/2021  Suicides
# 7116132  SYNTHETIC DATA       534127      2021    07/31/2021  Suicides
# 7116133  SYNTHETIC DATA       535156      2021    06/30/2021  Suicides
#
#          GEO_AREA  age  DOB  DOD  GENDER  GENDER_IDENTITY  SEX_ORIENT  \
# 7116131       NaN   16  NaN  NaN  1~Male              NaN         NaN
# 7116132       NaN   19  NaN  NaN  1~Male              NaN         NaN
# 7116133       NaN   24  NaN  NaN  1~Male              NaN         NaN
#
#          LEGAL_SEX     RACE              ETHNICITY  LIVING_ARRANGEMENT  \
# 7116131        NaN  1~White             99~Unknown                 NaN
# 7116132        NaN  1~White  2~Not Hispanic/Latinx                 NaN
# 7116133        NaN  1~White             99~Unknown                 NaN
#
#          EMPLOYMENT_STATUS          MARITAL_STATUS  \
# 7116131                NaN  1~Single-Never Married
# ...

# %% [markdown]
# ## Dataframe Attributes
#
# You can get a lot of helpful information from the attributes of the dataframe; specifically, we are going to look at dataframe dimensions, column names, column data types, and the ranges of column values. To get these, we can easily call some prebuilt attributes that are assigned to pandas dataframes. These help us to understand our data before we even start modifying it.

# %%
df.shape
# Out:
# (7116134, 20)

# %% [markdown]
# We can see that the dataset has 7116134 rows and 20 columns

# %%
df.columns
# Out:
# Index(['synthetic_data', 'MCI_UNIQ_ID', 'CALDR_YR', 'DATE_OF_EVENT', 'service',
#        'GEO_AREA', 'age', 'DOB', 'DOD', 'GENDER', 'GENDER_IDENTITY',
#        'SEX_ORIENT', 'LEGAL_SEX', 'RACE', 'ETHNICITY', 'LIVING_ARRANGEMENT',
#        'EMPLOYMENT_STATUS', 'MARITAL_STATUS', 'EDUCATION_LEVEL',
#        'VETERAN_FLAG'],
#       dtype='object')

# %% [markdown]
# Pandas dataframes also have a helpful method for easy summarization of the set, which you can call with `df.info()`.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7116134 entries, 0 to 7116133
# Data columns (total 20 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   synthetic_data      object
#  1   MCI_UNIQ_ID         int64
#  2   CALDR_YR            int64
#  3   DATE_OF_EVENT       object
#  4   service             object
#  5   GEO_AREA            float64
#  6   age                 int64
#  7   DOB                 float64
#  8   DOD                 float64
#  9   GENDER              object
#  10  GENDER_IDENTITY     float64
#  11  SEX_ORIENT          float64
#  12  LEGAL_SEX           float64
#  13  RACE                object
#  14  ETHNICITY           object
#  15  LIVING_ARRANGEMENT  float64
#  16  EMPLOYMENT_STATUS   float64
#  17  MARITAL_STATUS      object
#  18  EDUCATION_LEVEL     object
#  19  VETERAN_FLAG        float64
# dtypes: float64(9), int64(3), object(8)
# memory usage: 1.1+ GB

# %% [markdown]
# Another way to check the data types, if you just want that, is to use the `dtypes` attribute of the dataframe.

# %%
df.dtypes
# Out:
# synthetic_data         object
# MCI_UNIQ_ID             int64
# CALDR_YR                int64
# DATE_OF_EVENT          object
# service                object
# GEO_AREA              float64
# age                     int64
# DOB                   float64
# DOD                   float64
# GENDER                 object
# GENDER_IDENTITY       float64
# SEX_ORIENT            float64
# LEGAL_SEX             float64
# RACE                   object
# ETHNICITY              object
# LIVING_ARRANGEMENT    float64
# EMPLOYMENT_STATUS     float64
# MARITAL_STATUS         object
# EDUCATION_LEVEL        object
# VETERAN_FLAG          float64
# dtype: object

# %% [markdown]
#  - take a look at 3 random rows, it is important to inspect data beyond the head and tail

# %%
# set seed for random function so that we get same rows when re-run the cell
np.random.seed(17)
np.random.randint(2, df.shape[0],3)
# Out:
# array([ 589043, 5539985, 2078088])

# %%
np.random.randint(3, df.shape[0],3)
# Out:
# array([ 491929,  828732, 6417139])

# %%
# set seed for random function so that we get same rows when re-run the cell
np.random.seed(17)
df.iloc[np.random.randint(0, df.shape[0],3)]
# Out:
#          synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT  \
# 589041   SYNTHETIC DATA       364757      2021    10/31/2021
# 5539983  SYNTHETIC DATA       449747      2021    09/30/2021
# 2078086  SYNTHETIC DATA       109525      2021    09/30/2021
#
#                                        service  GEO_AREA  age  DOB  DOD  \
# 589041      Individuals_Receiving_DHS_Services       NaN   54  NaN  NaN
# 5539983  Individuals_Receiving_Income_Supports       NaN   51  NaN  NaN
# 2078086  Individuals_Receiving_Income_Supports       NaN   51  NaN  NaN
#
#          GENDER  GENDER_IDENTITY  SEX_ORIENT  LEGAL_SEX     RACE  \
# 589041   1~Male              NaN         NaN        NaN  1~White
# 5539983  1~Male              NaN         NaN        NaN  1~White
# 2078086  1~Male              NaN         NaN        NaN  1~White
#
#                      ETHNICITY  LIVING_ARRANGEMENT  EMPLOYMENT_STATUS  \
# 589041   2~Not Hispanic/Latinx                 NaN                NaN
# ...

# %% [markdown]
#  - take a look at the record for a specific MCI_UNIQ_ID, say merchant 364757 from above result

# %%
df[df['MCI_UNIQ_ID'] == 364757].sort_values("DATE_OF_EVENT").head(10)
# someone receiving multiple services
# Out:
#          synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT  \
# 6710438  SYNTHETIC DATA       364757      2021    01/31/2021
# 4675581  SYNTHETIC DATA       364757      2021    01/31/2021
# 589034   SYNTHETIC DATA       364757      2021    02/28/2021
# 4675582  SYNTHETIC DATA       364757      2021    02/28/2021
# 589035   SYNTHETIC DATA       364757      2021    03/31/2021
# 6710439  SYNTHETIC DATA       364757      2021    03/31/2021
# 4675583  SYNTHETIC DATA       364757      2021    03/31/2021
# 6710440  SYNTHETIC DATA       364757      2021    04/30/2021
# 4675584  SYNTHETIC DATA       364757      2021    04/30/2021
# 589036   SYNTHETIC DATA       364757      2021    05/31/2021
#
#                                               service  GEO_AREA  age  DOB  \
# 6710438  Individuals_Receiving_Mental_Health_Services       NaN   54  NaN
# 4675581         Individuals_Receiving_Income_Supports       NaN   54  NaN
# ...

# %%
df[df['MCI_UNIQ_ID'] == 449747].sort_values("DATE_OF_EVENT")
# Out:
#          synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT  \
# 5539976  SYNTHETIC DATA       449747      2021    01/31/2021
# 5539977  SYNTHETIC DATA       449747      2021    03/31/2021
# 5539978  SYNTHETIC DATA       449747      2021    04/30/2021
# 5539979  SYNTHETIC DATA       449747      2021    05/31/2021
# 5539980  SYNTHETIC DATA       449747      2021    06/30/2021
# 5539981  SYNTHETIC DATA       449747      2021    07/31/2021
# 5539982  SYNTHETIC DATA       449747      2021    08/31/2021
# 5539983  SYNTHETIC DATA       449747      2021    09/30/2021
# 5539984  SYNTHETIC DATA       449747      2021    10/31/2021
# 5539985  SYNTHETIC DATA       449747      2021    11/30/2021
#
#                                        service  GEO_AREA  age  DOB  DOD  \
# 5539976  Individuals_Receiving_Income_Supports       NaN   51  NaN  NaN
# 5539977  Individuals_Receiving_Income_Supports       NaN   51  NaN  NaN
# 5539978  Individuals_Receiving_Income_Supports       NaN   51  NaN  NaN
# ...

# %% [markdown]
# Or, use df.query
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %%
df.query("MCI_UNIQ_ID == 449747").sort_values(by="DATE_OF_EVENT",ascending=False)
# Out:
#          synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT  \
# 5539985  SYNTHETIC DATA       449747      2021    11/30/2021
# 5539984  SYNTHETIC DATA       449747      2021    10/31/2021
# 5539983  SYNTHETIC DATA       449747      2021    09/30/2021
# 5539982  SYNTHETIC DATA       449747      2021    08/31/2021
# 5539981  SYNTHETIC DATA       449747      2021    07/31/2021
# 5539980  SYNTHETIC DATA       449747      2021    06/30/2021
# 5539979  SYNTHETIC DATA       449747      2021    05/31/2021
# 5539978  SYNTHETIC DATA       449747      2021    04/30/2021
# 5539977  SYNTHETIC DATA       449747      2021    03/31/2021
# 5539976  SYNTHETIC DATA       449747      2021    01/31/2021
#
#                                        service  GEO_AREA  age  DOB  DOD  \
# 5539985  Individuals_Receiving_Income_Supports       NaN   51  NaN  NaN
# 5539984  Individuals_Receiving_Income_Supports       NaN   51  NaN  NaN
# 5539983  Individuals_Receiving_Income_Supports       NaN   51  NaN  NaN
# ...

# %%
df.iloc[:3] # rows 0 to 2, i.e.,  0, 1, 2
# Out:
#    synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT  \
# 0  SYNTHETIC DATA         1626      2021    01/31/2021
# 1  SYNTHETIC DATA         1626      2021    02/28/2021
# 2  SYNTHETIC DATA         1626      2021    03/31/2021
#
#                                              service  GEO_AREA  age  DOB  DOD  \
# 0  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
# 1  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
# 2  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
#
#    GENDER  GENDER_IDENTITY  SEX_ORIENT  LEGAL_SEX     RACE   ETHNICITY  \
# 0  1~Male              NaN         NaN        NaN  1~White  99~Unknown
# 1  1~Male              NaN         NaN        NaN  1~White  99~Unknown
# 2  1~Male              NaN         NaN        NaN  1~White  99~Unknown
#
#    LIVING_ARRANGEMENT  EMPLOYMENT_STATUS MARITAL_STATUS  \
# 0                 NaN                NaN     99~Unknown
# ...

# %%
df.iloc[[0,2]] # rows 0 and 2
# Out:
#    synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT  \
# 0  SYNTHETIC DATA         1626      2021    01/31/2021
# 2  SYNTHETIC DATA         1626      2021    03/31/2021
#
#                                              service  GEO_AREA  age  DOB  DOD  \
# 0  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
# 2  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN  NaN
#
#    GENDER  GENDER_IDENTITY  SEX_ORIENT  LEGAL_SEX     RACE   ETHNICITY  \
# 0  1~Male              NaN         NaN        NaN  1~White  99~Unknown
# 2  1~Male              NaN         NaN        NaN  1~White  99~Unknown
#
#    LIVING_ARRANGEMENT  EMPLOYMENT_STATUS MARITAL_STATUS  \
# 0                 NaN                NaN     99~Unknown
# 2                 NaN                NaN     99~Unknown
#
#                  EDUCATION_LEVEL  VETERAN_FLAG
# 0  9-12~High School (grade 9-12)           NaN
# 2  9-12~High School (grade 9-12)           NaN

# %%
df.iloc[:,4] # 4th column, starting from 0, the service
# Out:
# 0          Children_Attending_Early_Childhood_Programs_Ma...
# 1          Children_Attending_Early_Childhood_Programs_Ma...
# 2          Children_Attending_Early_Childhood_Programs_Ma...
# 3          Children_Attending_Early_Childhood_Programs_Ma...
# 4          Children_Attending_Early_Childhood_Programs_Ma...
#                                  ...
# 7116129                                             Suicides
# 7116130                                             Suicides
# 7116131                                             Suicides
# 7116132                                             Suicides
# 7116133                                             Suicides
# Name: service, Length: 7116134, dtype: object

# %%
df.iloc[:,[3,8]] # the 3rd and 8th column, starting from 0
# Out:
#         DATE_OF_EVENT  DOD
# 0          01/31/2021  NaN
# 1          02/28/2021  NaN
# 2          03/31/2021  NaN
# 3          04/30/2021  NaN
# 4          05/31/2021  NaN
# ...               ...  ...
# 7116129    06/30/2021  NaN
# 7116130    04/30/2021  NaN
# 7116131    11/30/2021  NaN
# 7116132    07/31/2021  NaN
# 7116133    06/30/2021  NaN
#
# [7116134 rows x 2 columns]

# %%
df.loc[:,['MCI_UNIQ_ID']]
# Out:
#          MCI_UNIQ_ID
# 0               1626
# 1               1626
# 2               1626
# 3               1626
# 4               1626
# ...              ...
# 7116129       530832
# 7116130       532121
# 7116131       533991
# 7116132       534127
# 7116133       535156
#
# [7116134 rows x 1 columns]

# %%
df.loc[:,['MCI_UNIQ_ID','service']]
# Out:
#          MCI_UNIQ_ID                                            service
# 0               1626  Children_Attending_Early_Childhood_Programs_Ma...
# 1               1626  Children_Attending_Early_Childhood_Programs_Ma...
# 2               1626  Children_Attending_Early_Childhood_Programs_Ma...
# 3               1626  Children_Attending_Early_Childhood_Programs_Ma...
# 4               1626  Children_Attending_Early_Childhood_Programs_Ma...
# ...              ...                                                ...
# 7116129       530832                                           Suicides
# 7116130       532121                                           Suicides
# 7116131       533991                                           Suicides
# 7116132       534127                                           Suicides
# 7116133       535156                                           Suicides
#
# [7116134 rows x 2 columns]

# %%
df[['MCI_UNIQ_ID','service']]
# Out:
#          MCI_UNIQ_ID                                            service
# 0               1626  Children_Attending_Early_Childhood_Programs_Ma...
# 1               1626  Children_Attending_Early_Childhood_Programs_Ma...
# 2               1626  Children_Attending_Early_Childhood_Programs_Ma...
# 3               1626  Children_Attending_Early_Childhood_Programs_Ma...
# 4               1626  Children_Attending_Early_Childhood_Programs_Ma...
# ...              ...                                                ...
# 7116129       530832                                           Suicides
# 7116130       532121                                           Suicides
# 7116131       533991                                           Suicides
# 7116132       534127                                           Suicides
# 7116133       535156                                           Suicides
#
# [7116134 rows x 2 columns]

# %%
df.iloc[lambda x: x.index % 2 == 0] # all the even numbered rows
# Out:
#          synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT  \
# 0        SYNTHETIC DATA         1626      2021    01/31/2021
# 2        SYNTHETIC DATA         1626      2021    03/31/2021
# 4        SYNTHETIC DATA         1626      2021    05/31/2021
# 6        SYNTHETIC DATA         3775      2021    01/31/2021
# 8        SYNTHETIC DATA         3775      2021    03/31/2021
# ...                 ...          ...       ...           ...
# 7116124  SYNTHETIC DATA       530089      2021    02/28/2021
# 7116126  SYNTHETIC DATA       530573      2021    02/28/2021
# 7116128  SYNTHETIC DATA       530765      2021    06/30/2021
# 7116130  SYNTHETIC DATA       532121      2021    04/30/2021
# 7116132  SYNTHETIC DATA       534127      2021    07/31/2021
#
#                                                    service  GEO_AREA  age  \
# 0        Children_Attending_Early_Childhood_Programs_Ma...       NaN    5
# 2        Children_Attending_Early_Childhood_Programs_Ma...       NaN    5
# ...

# %% [markdown]
# Reference:
#
# * lambda function: https://www.w3schools.com/python/python_lambda.asp
#
# * index of the dataframe: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.index.html

# %%
df.at[2,"DATE_OF_EVENT"], df.at[2,'EDUCATION_LEVEL']
# Out:
# ('03/31/2021', '9-12~High School (grade 9-12)')

# %%
df.iat[2,3], df.iat[2,18]
# Out:
# ('03/31/2021', '9-12~High School (grade 9-12)')

# %% [markdown]
# ### filtering on date

# %%
df_filtered = df[df["DATE_OF_EVENT"] == "02/28/2021"] # all the rows with specific date of event
df_filtered.head(10)
# Out:
#     synthetic_data  MCI_UNIQ_ID  CALDR_YR DATE_OF_EVENT  \
# 1   SYNTHETIC DATA         1626      2021    02/28/2021
# 7   SYNTHETIC DATA         3775      2021    02/28/2021
# 19  SYNTHETIC DATA         5570      2021    02/28/2021
# 29  SYNTHETIC DATA         7912      2021    02/28/2021
# 35  SYNTHETIC DATA         9265      2021    02/28/2021
# 41  SYNTHETIC DATA        11411      2021    02/28/2021
# 47  SYNTHETIC DATA        13104      2021    02/28/2021
# 59  SYNTHETIC DATA        14728      2021    02/28/2021
# 65  SYNTHETIC DATA        16102      2021    02/28/2021
# 80  SYNTHETIC DATA        19600      2021    02/28/2021
#
#                                               service  GEO_AREA  age  DOB  \
# 1   Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN
# 7   Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN
# 19  Children_Attending_Early_Childhood_Programs_Ma...       NaN    5  NaN
# ...

# %% [markdown]
# ## generating aggregates for further inspections

# %% [markdown]
# One way to get an overview of the data values is to use another helpful function, `df.describe()`. This will provide several summary statistics for you for each of the columns in the set.

# %%
df.describe()
# Out:
#         MCI_UNIQ_ID   CALDR_YR  GEO_AREA           age  DOB  DOD  \
# count  7.116134e+06  7116134.0       0.0  7.116134e+06  0.0  0.0
# mean   2.674853e+05     2021.0       NaN  3.267702e+01  NaN  NaN
# std    1.544397e+05        0.0       NaN  2.258095e+01  NaN  NaN
# min    1.000000e+00     2021.0       NaN  0.000000e+00  NaN  NaN
# 25%    1.337730e+05     2021.0       NaN  1.300000e+01  NaN  NaN
# 50%    2.675410e+05     2021.0       NaN  3.000000e+01  NaN  NaN
# 75%    4.010820e+05     2021.0       NaN  4.900000e+01  NaN  NaN
# max    5.356080e+05     2021.0       NaN  1.210000e+02  NaN  NaN
#
#        GENDER_IDENTITY  SEX_ORIENT  LEGAL_SEX  LIVING_ARRANGEMENT  \
# count              0.0         0.0        0.0                 0.0
# mean               NaN         NaN        NaN                 NaN
# std                NaN         NaN        NaN                 NaN
# min                NaN         NaN        NaN                 NaN
# ...

# %% [markdown]
# * not every column was included in the stats computation, due to "object" type
# * NaN columns were included in the summary
#
# * for the numerical type, we may also like to display the results in format easier for reading, as for "age" column
#
# * In some cases, these are not helpful, like in the IDs portion, having the mean ID value is not important. Same with calendar year, especially since these are all from the same year. But something to note is that the values for the mean, std error, and quartiles will not show up if there are ANY NaN values in the column. So we need to find out where these NaN values are.

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
df.age.describe()
# Out:
# count   7116134.000
# mean         32.677
# std          22.581
# min           0.000
# 25%          13.000
# 50%          30.000
# 75%          49.000
# max         121.000
# Name: age, dtype: float64

# %% [markdown]
# We can also find the number of unique entries in the dataframe. This can be important as in some cases we may not want duplicates. In the case of these data from Allegheny County, unique IDs are important as each one will correspond to a single person, and we can track that person across their usage of many different services.

# %%
df.nunique() # number of unique values for each column
# Out:
# synthetic_data             1
# MCI_UNIQ_ID           533799
# CALDR_YR                   1
# DATE_OF_EVENT             12
# service                   22
# GEO_AREA                   0
# age                      112
# DOB                        0
# DOD                        0
# GENDER                     3
# GENDER_IDENTITY            0
# SEX_ORIENT                 0
# LEGAL_SEX                  0
# RACE                       7
# ETHNICITY                  3
# LIVING_ARRANGEMENT         0
# EMPLOYMENT_STATUS          0
# MARITAL_STATUS             7
# EDUCATION_LEVEL            8
# VETERAN_FLAG               0
# dtype: int64

# %% [markdown]
# We can see there are 533799 unique ID's among the 7116134 records, about 13 rows per ID on average. Could this mean every recipient uses DHS services every month?
#
# The columns with zero unique values have no values at all, meaning the entire columns are NaN. We could remove them.
#
# what else can you conclude from this above result? what about the columns with 1 value?

# %%
df.CALDR_YR.unique(), df.synthetic_data.unique() # the actua unique values of the columns
# Out:
# (array([2021]), array(['SYNTHETIC DATA'], dtype=object))

# %% [markdown]
# we can see both columns do not have much information, we already knew the data is synthetic and is for year 2021.

# %%
df.service.unique()
# Out:
# array(['Children_Attending_Early_Childhood_Programs_Managed_by_DHS',
#        'Children_in_Care', 'Children_Receiving_Child_Welfare_Services',
#        'Children_Receiving_DHS_Funded_Out_of_School_Programs',
#        'Children_Receiving_Early_Intervention_Services',
#        'Families_Receiving_Child_Welfare_Services', 'Homeless_Population',
#        'Homicides', 'Individuals_Receiving_DHS_Services',
#        'Individuals_Receiving_Family_Strengthening_Programs',
#        'Individuals_Receiving_Homelessness_and_Housing_Services',
#        'Individuals_Receiving_Income_Supports',
#        'Individuals_Receiving_Intellectual_Disability_Services',
#        'Individuals_Receiving_Mental_Health_Services',
#        'Individuals_Receiving_Substance_Use_Disorder_Services',
#        'Involuntary_Commitments', 'Jail_Population',
#        'Mental_Health_Crises', 'Older_Adults_Receiving_Services',
#        'Overdoses', 'Parents_Receiving_Child_Welfare_Services',
# ...

# %% [markdown]
# ## Finding NaN values
#
# To get the number of NaN (N/A or NA, as they are sometimes called), we can use the `isna()` method in combination with the `sum()` method.

# %%
df.isna().sum()
# Out:
# synthetic_data              0
# MCI_UNIQ_ID                 0
# CALDR_YR                    0
# DATE_OF_EVENT               0
# service                     0
# GEO_AREA              7116134
# age                         0
# DOB                   7116134
# DOD                   7116134
# GENDER                      0
# GENDER_IDENTITY       7116134
# SEX_ORIENT            7116134
# LEGAL_SEX             7116134
# RACE                        0
# ETHNICITY                   0
# LIVING_ARRANGEMENT    7116134
# EMPLOYMENT_STATUS     7116134
# MARITAL_STATUS              0
# EDUCATION_LEVEL             0
# VETERAN_FLAG          7116134
# dtype: int64

# %%
df.isnull().sum()
# Out:
# synthetic_data              0
# MCI_UNIQ_ID                 0
# CALDR_YR                    0
# DATE_OF_EVENT               0
# service                     0
# GEO_AREA              7116134
# age                         0
# DOB                   7116134
# DOD                   7116134
# GENDER                      0
# GENDER_IDENTITY       7116134
# SEX_ORIENT            7116134
# LEGAL_SEX             7116134
# RACE                        0
# ETHNICITY                   0
# LIVING_ARRANGEMENT    7116134
# EMPLOYMENT_STATUS     7116134
# MARITAL_STATUS              0
# EDUCATION_LEVEL             0
# VETERAN_FLAG          7116134
# dtype: int64

# %% [markdown]
# Those columns with 7116134 NaN's are the columns filled with NaN completely.
#
# We can see the columns ['GEO_AREA', 'DOB', 'DOD', 'GENDER_IDENTITY', 'SEX_ORIENT', 'LEGAL_SEX', 'LIVING_ARRANGEMENT', 'EMPLOYMENT_STATUS', 'VETERAN_FLAG'] have only NaN values.

# %% [markdown]
# ## Histogram

# %%
df[df["GENDER"]=="1~Male"]["age"].head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# Name: age, dtype: int64

# %%
import matplotlib.pyplot as plt
#make a histogram for the age column in df
plt.hist(df['age'], bins = 20, color = 'blue', edgecolor = 'black', density=True)

#add normal distribution
mu = df['age'].mean()
sigma = df['age'].std()
x = np.linspace(df['age'].min(), df['age'].max(), 100)
y = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (x - mu)**2 / (2 * sigma**2))

plt.plot(x, y, color = 'red')

plt.title('Age Histogram')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns

fig, ((ax0, ax1)) = plt.subplots(nrows=1, ncols=2)

ax0.hist(df[df["GENDER"]=="1~Male"]["age"], bins=10, density=True, histtype='bar', color="red", edgecolor = "black")
ax0.set_title('Age Distribution of Male')

ax1.hist(df[df["GENDER"]=="2~Female"]["age"], bins=10, density=True, histtype='bar', color = "green", edgecolor = "black")
ax1.set_title('Age Distribution of Female')

fig.tight_layout()
plt.show()

# %%
sns.countplot(x = df['EDUCATION_LEVEL'])
plt.title('Education Level Distribution')
plt.xlabel('Education Level')
plt.xticks(rotation=90)
plt.ylabel('Frequency')
plt.show()

# %%
sns.countplot(y = df['EDUCATION_LEVEL'])
plt.title('Education Level Distribution')
plt.ylabel('Education Level')
plt.xlabel('Frequency')
plt.show()

# %%
### notice the number of "unknown" education levels are very high. This should be treated differently from NaN value in data.

# %%
#we want to make a boxplot of age, separated by gender
#we can use seaborn for this
import seaborn as sns

sns.boxplot(data = df, x = "GENDER", y = "age")
plt.title('Age Distribution of DHS Service')
plt.show()

# %%
sns.barplot(df.groupby('RACE')['GENDER'].count())
# Out:
# <Axes: xlabel='RACE', ylabel='GENDER'>

# %% [markdown]
# ### basic aggregations

# %%
df.groupby("service").count()
# Out:
#                                                     synthetic_data  \
# service
# Children_Attending_Early_Childhood_Programs_Man...            2302
# Children_Receiving_Child_Welfare_Services                    50373
# Children_Receiving_DHS_Funded_Out_of_School_Pro...            4606
# Children_Receiving_Early_Intervention_Services               45923
# Children_in_Care                                             18442
# Families_Receiving_Child_Welfare_Services                    23473
# Homeless_Population                                          13950
# Homicides                                                      172
# Individuals_Receiving_DHS_Services                          626722
# Individuals_Receiving_Family_Strengthening_Prog...           28110
# Individuals_Receiving_Homelessness_and_Housing_...          148968
# Individuals_Receiving_Income_Supports                      5450993
# Individuals_Receiving_Intellectual_Disability_S...           74145
# ...

# %%
df.groupby("service").count().sort_values(by="MCI_UNIQ_ID",ascending=False)
# Out:
#                                                     synthetic_data  \
# service
# Individuals_Receiving_Income_Supports                      5450993
# Individuals_Receiving_DHS_Services                          626722
# Individuals_Receiving_Mental_Health_Services                324241
# Individuals_Receiving_Homelessness_and_Housing_...          148968
# Older_Adults_Receiving_Services                             131153
# Individuals_Receiving_Substance_Use_Disorder_Se...           74737
# Individuals_Receiving_Intellectual_Disability_S...           74145
# Parents_Receiving_Child_Welfare_Services                     54035
# Children_Receiving_Child_Welfare_Services                    50373
# Children_Receiving_Early_Intervention_Services               45923
# Individuals_Receiving_Family_Strengthening_Prog...           28110
# Jail_Population                                              26987
# Families_Receiving_Child_Welfare_Services                    23473
# ...

# %%
df.groupby("service").nunique().sort_values(by="MCI_UNIQ_ID",ascending=False)
# Out:
#                                                     synthetic_data  \
# service
# Individuals_Receiving_Income_Supports                            1
# Individuals_Receiving_DHS_Services                               1
# Individuals_Receiving_Mental_Health_Services                     1
# Individuals_Receiving_Homelessness_and_Housing_...               1
# Older_Adults_Receiving_Services                                  1
# Individuals_Receiving_Substance_Use_Disorder_Se...               1
# Children_Receiving_Child_Welfare_Services                        1
# Mental_Health_Crises                                             1
# Parents_Receiving_Child_Welfare_Services                         1
# Jail_Population                                                  1
# Children_Receiving_Early_Intervention_Services                   1
# Individuals_Receiving_Intellectual_Disability_S...               1
# Involuntary_Commitments                                          1
# ...

# %%
df.groupby(["RACE","service"]).count().sort_values(by="MCI_UNIQ_ID",ascending=False)
# Out:
#                                                                                  synthetic_data  \
# RACE                               service
# 1~White                            Individuals_Receiving_Income_Supports                3420451
# 2~Black/African American           Individuals_Receiving_Income_Supports                1621768
# 1~White                            Individuals_Receiving_DHS_Services                    397378
#                                    Individuals_Receiving_Mental_Health_Services          225401
# 99~Unknown                         Individuals_Receiving_Income_Supports                 218606
# ...                                                                                         ...
# 7~Other Single Race                Suicides                                                   2
# 5~Native American/Pacific Islander Mental_Health_Crises                                       1
# ...

# %%
df.groupby("MCI_UNIQ_ID").count().sort_values(by="service", ascending=False)
# Out:
#              synthetic_data  CALDR_YR  DATE_OF_EVENT  service  GEO_AREA  age  \
# MCI_UNIQ_ID
# 178128                   89        89             89       89         0   89
# 392121                   89        89             89       89         0   89
# 306750                   88        88             88       88         0   88
# 221385                   85        85             85       85         0   85
# 121055                   85        85             85       85         0   85
# ...                     ...       ...            ...      ...       ...  ...
# 82846                     1         1              1        1         0    1
# 302861                    1         1              1        1         0    1
# 143362                    1         1              1        1         0    1
# 112358                    1         1              1        1         0    1
# 109229                    1         1              1        1         0    1
#
# ...

# %%
df.groupby("RACE")['age'].mean()
# Out:
# RACE
# 1~White                              34.719
# 2~Black/African American             30.469
# 4~Asian                              29.759
# 5~Native American/Pacific Islander   36.226
# 6~Two or More Races                  19.323
# 7~Other Single Race                  18.286
# 99~Unknown                           19.513
# Name: age, dtype: float64

# %%
df.groupby("RACE")['age'].agg('mean')
# Out:
# RACE
# 1~White                              34.719
# 2~Black/African American             30.469
# 4~Asian                              29.759
# 5~Native American/Pacific Islander   36.226
# 6~Two or More Races                  19.323
# 7~Other Single Race                  18.286
# 99~Unknown                           19.513
# Name: age, dtype: float64

# %%
# agg can be called with custom fuctions
def data_range(x):
    return x.max() - x.min()
df.groupby("RACE")['age'].agg('mean'), df.groupby("RACE")['age'].agg(data_range)
# Out:
# (RACE
#  1~White                              34.719
#  2~Black/African American             30.469
#  4~Asian                              29.759
#  5~Native American/Pacific Islander   36.226
#  6~Two or More Races                  19.323
#  7~Other Single Race                  18.286
#  99~Unknown                           19.513
#  Name: age, dtype: float64,
#  RACE
#  1~White                               113
#  2~Black/African American              121
#  4~Asian                               109
#  5~Native American/Pacific Islander     96
#  6~Two or More Races                    96
#  7~Other Single Race                    99
#  99~Unknown                            107
#  Name: age, dtype: int64)

# %% [markdown]
# ## In class exercises
# Answer the following questions:
#  - Which recipient has the highest number of records among all recipients?
#  - how many recipients used the services in January?
#  - for each month, how many recipients used services?
#  - Given an ID, how many months did the particular recipient (by ID) use the service? e.g., 449747
#  - do the statistics on the columns make sense? e.g., are there any inconsistencies between age and education level?

# %% [markdown]
# ### Exercise 1

# %%
df.groupby("MCI_UNIQ_ID").count().sort_values(by='service', ascending=False).head(5)
# Out:
#              synthetic_data  CALDR_YR  DATE_OF_EVENT  service  GEO_AREA  age  \
# MCI_UNIQ_ID
# 178128                   89        89             89       89         0   89
# 392121                   89        89             89       89         0   89
# 306750                   88        88             88       88         0   88
# 221385                   85        85             85       85         0   85
# 121055                   85        85             85       85         0   85
#
#              DOB  DOD  GENDER  GENDER_IDENTITY  SEX_ORIENT  LEGAL_SEX  RACE  \
# MCI_UNIQ_ID
# 178128         0    0      89                0           0          0    89
# 392121         0    0      89                0           0          0    89
# 306750         0    0      88                0           0          0    88
# 221385         0    0      85                0           0          0    85
# 121055         0    0      85                0           0          0    85
#
# ...

# %% [markdown]
# 178128 and 392121 both have the highest number of records among all recipients with 89 records

# %% [markdown]
# ### Exercise 2

# %%
df[df['DATE_OF_EVENT']=='01/31/2021'].nunique()
# Out:
# synthetic_data             1
# MCI_UNIQ_ID           457593
# CALDR_YR                   1
# DATE_OF_EVENT              1
# service                   22
# GEO_AREA                   0
# age                      112
# DOB                        0
# DOD                        0
# GENDER                     3
# GENDER_IDENTITY            0
# SEX_ORIENT                 0
# LEGAL_SEX                  0
# RACE                       7
# ETHNICITY                  3
# LIVING_ARRANGEMENT         0
# EMPLOYMENT_STATUS          0
# MARITAL_STATUS             7
# EDUCATION_LEVEL            8
# VETERAN_FLAG               0
# dtype: int64

# %% [markdown]
# We can see that in January, there were 457,593 unique recipients who used services

# %% [markdown]
# ### Exercise 3

# %%
df.groupby('DATE_OF_EVENT').nunique()
# Out:
#                synthetic_data  MCI_UNIQ_ID  CALDR_YR  service  GEO_AREA  age  \
# DATE_OF_EVENT
# 01/31/2021                  1       457593         1       22         0  112
# 02/28/2021                  1       461207         1       22         0  112
# 03/31/2021                  1       465763         1       22         0  112
# 04/30/2021                  1       469090         1       22         0  112
# 05/31/2021                  1       467082         1       22         0  112
# 06/30/2021                  1       470430         1       22         0  112
# 07/31/2021                  1       473887         1       22         0  112
# 08/31/2021                  1       477523         1       22         0  112
# 09/30/2021                  1       484128         1       22         0  112
# 10/31/2021                  1       489308         1       22         0  112
# 11/30/2021                  1       494557         1       22         0  112
# ...

# %% [markdown]
# the table above shows how many unique recipients (found in the MCI_UNIQ_ID column) there were for each month

# %% [markdown]
# ### Exercise 4

# %%
df[df['MCI_UNIQ_ID']==449747].nunique()
# Out:
# synthetic_data         1
# MCI_UNIQ_ID            1
# CALDR_YR               1
# DATE_OF_EVENT         10
# service                1
# GEO_AREA               0
# age                    1
# DOB                    0
# DOD                    0
# GENDER                 1
# GENDER_IDENTITY        0
# SEX_ORIENT             0
# LEGAL_SEX              0
# RACE                   1
# ETHNICITY              1
# LIVING_ARRANGEMENT     0
# EMPLOYMENT_STATUS      0
# MARITAL_STATUS         1
# EDUCATION_LEVEL        1
# VETERAN_FLAG           0
# dtype: int64

# %% [markdown]
# The list above shows that recipient 449747 recieved service in 10 months out of the year

# %% [markdown]
# ### Exercise 5

# %%
sns.countplot(y = df['EDUCATION_LEVEL'])
plt.title('Education Level Distribution')
plt.ylabel('Education Level')
plt.xlabel('Frequency')
plt.show()

# %%
#make a histogram for the age column in df
plt.hist(df['age'], bins = 20, color = 'blue', edgecolor = 'black', density=True)

#add normal distribution
mu = df['age'].mean()
sigma = df['age'].std()
x = np.linspace(df['age'].min(), df['age'].max(), 100)
y = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (x - mu)**2 / (2 * sigma**2))

plt.plot(x, y, color = 'red')

plt.title('Age Histogram')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df.groupby('EDUCATION_LEVEL')['age'].count()
# Out:
# EDUCATION_LEVEL
# 1-5~Elementary School (Grade 1-5)         616684
# 6-8~Middle School (Grade 6-8)             486825
# 9-12~High School (grade 9-12)            2999610
# 99~Unknown                               2265116
# GED~High School Diploma/GED Completed     276967
# GRAD COMP~College Degree                  152923
# GRAD~Graduate Degree                       38044
# UNDERGRAD~Some College                    279965
# Name: age, dtype: int64

# %%
df.query("age > 18 and EDUCATION_LEVEL=='9-12~High School (grade 9-12)'").nunique()
# Out:
# synthetic_data             1
# MCI_UNIQ_ID           148231
# CALDR_YR                   1
# DATE_OF_EVENT             12
# service                   18
# GEO_AREA                   0
# age                       93
# DOB                        0
# DOD                        0
# GENDER                     3
# GENDER_IDENTITY            0
# SEX_ORIENT                 0
# LEGAL_SEX                  0
# RACE                       7
# ETHNICITY                  3
# LIVING_ARRANGEMENT         0
# EMPLOYMENT_STATUS          0
# MARITAL_STATUS             7
# EDUCATION_LEVEL            1
# VETERAN_FLAG               0
# dtype: int64

# %%
df[df['age']>18].count()
# Out:
# synthetic_data        4761994
# MCI_UNIQ_ID           4761994
# CALDR_YR              4761994
# DATE_OF_EVENT         4761994
# service               4761994
# GEO_AREA                    0
# age                   4761994
# DOB                         0
# DOD                         0
# GENDER                4761994
# GENDER_IDENTITY             0
# SEX_ORIENT                  0
# LEGAL_SEX                   0
# RACE                  4761994
# ETHNICITY             4761994
# LIVING_ARRANGEMENT          0
# EMPLOYMENT_STATUS           0
# MARITAL_STATUS        4761994
# EDUCATION_LEVEL       4761994
# VETERAN_FLAG                0
# dtype: int64

# %% [markdown]
# It looks like there are about 1.7 million people over the age of 18 who don't have a high school diploma.
