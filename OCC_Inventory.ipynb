# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

os.chdir('/Users/joshwinnes/Library/Mobile Documents/com~apple~CloudDocs/Wheaton College/fall 2024/topics in data science/data')
df = pd.read_csv('OCC data - all items.csv')

df
# Out:
#     item_id                   item_name item_class item_type  amount_per_box  \
# 0         1               sticker_sheet      small    school               1
# 1         2          matchbox_cars_pack     medium       toy               1
# 2         3                   washcloth     medium  clothing               1
# 3         4                    notebook      large    school               1
# 4         5                   foam_ball      large       toy               1
# 5         6  english_spanish_flashcards     medium    school               1
# 6         7              drawstring bag      large    school               1
# 7         8          coloring_tool_pack     medium    school               1
# 8         9                dixon_pencil      small    school               2
# 9        10                  fun_pencil      small    school               1
# 10       11                      eraser      small    school               1
# ...

# %%
df.groupby(['item_class', 'gender'])['in_stock'].sum()
# Out:
# item_class  gender
# large       both       22
#             boy        25
#             girl       45
# medium      both      140
#             boy        10
#             girl       55
# small       both      340
#             girl      220
# Name: in_stock, dtype: int64

# %% [markdown]
# ### **packing rules**

# %% [markdown]
# **Boy Boxes**
#
# Looking to fill 20 boxes
# - 1 Large item
# - 3 medium items
# - standard small items:
#     - 2-3 pencils
#     - 2 erasers
#     - 1 sharpener
#     - sheet of stickers
#
# **Girl Rules**
#
# Looking to fill 30 boxes
# - 2 Large items
# - 2 medium items
# - standard small items:
#     - 2-3 pencils
#     - 2 erasers
#     - 1 sharpener
#     - sheet of stickers

# %%
df_small = df.query('item_class == "small"')
df_small['amount_per_box'] = df_small['in_stock']/50
df_small
# Out:
# /var/folders/99/6591xgpn4sq1ypfgnrzy_7n80000gn/T/ipykernel_97641/2636681736.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['amount_per_box'] = df_small['in_stock']/50
#     item_id         item_name item_class item_type  amount_per_box  in_stock  \
# 0         1     sticker_sheet      small    school            1.30        65
# 8         9      dixon_pencil      small    school            0.80        40
# 9        10        fun_pencil      small    school            1.44        72
# 10       11            eraser      small    school            1.96        98
# 11       12  pencil_sharpener      small    school            1.00        50
# 12       13         hair_ties      small  clothing            4.40       220
# ...

# %%
df_medium = df.query('item_class == "medium"')
df_medium
# Out:
#     item_id                   item_name item_class item_type  amount_per_box  \
# 1         2          matchbox_cars_pack     medium       toy               1
# 2         3                   washcloth     medium  clothing               1
# 5         6  english_spanish_flashcards     medium    school               1
# 7         8          coloring_tool_pack     medium    school               1
# 14       15                    pom_poms     medium       toy               1
# 15       16             keychain_animal     medium       toy               1
# 16       17                         fan     medium       toy               1
# 20       21                  play_dough     medium       toy               1
# 21       22           glow_squeeze_ball     medium       toy               1
# 23       24           head_bands_single     medium  clothing               1
# 25       26                       combs     medium  clothing               1
#
# ...

# %%
df_large = df.query('item_class == "large"')
df_large
# Out:
#     item_id            item_name item_class item_type  amount_per_box  \
# 3         4             notebook      large    school               1
# 4         5            foam_ball      large       toy               1
# 6         7       drawstring bag      large    school               1
# 13       14          fuzzy_socks      large  clothing               1
# 17       18           teddy_bear      large       toy               1
# 22       23  squishy_foam_animal      large       toy               1
# 24       25           baby_dolls      large       toy               1
# 26       27        foam_football      large       toy               1
# 27       28    rubber_spiky_ball      large       toy               1
#
#     in_stock gender    2-4    5-9  10-12 Unnamed: 10
# 3         20   both  False   True   True         NaN
# 4          5    boy   True   True   True         NaN
# 6         10    boy  False  False   True         NaN
# 13        17   girl  False   True   True         NaN
# ...
